# %%
import pandas as pd
import numpy as np
import os
import glob
import os
import subprocess
import pandas as pd
import numpy as np
from scipy.stats import iqr
from statsmodels.formula.api import ols
from scipy.stats import zscore
from nipype.interfaces.fsl import ImageMaths
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import pandas as pd
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests
# Create bar plot
plt.style.use('seaborn-v0_8-poster')
#plt.style.use('seaborn-v0_8')
fontsize = 11
plt.rcParams.update({
    "font.size": fontsize,          # Global font size
    "axes.labelsize": fontsize,     # X and Y axis labels
    "axes.titlesize": fontsize,     # Title (if used)
    "xtick.labelsize": fontsize,    # X-axis tick labels
    "ytick.labelsize": fontsize,    # Y-axis tick labels
    "legend.fontsize": fontsize,    # Legend font size
})

# %%
project_dir = '/Users/xiaoqianxiao/projects/OCD'
data_dir = os.path.join(project_dir, 'results/NW_group_roi_roi')
result_dir = os.path.join(project_dir, 'results/visualization/NW_group_roi_roi')
if not os.path.exists(result_dir):
    os.makedirs(result_dir, exist_ok=True)

# %%
group_diff_file = os.path.join(data_dir, 'group_diff_baseline_harvard_oxford_cort-maxprob-thr25-2mm_roiroi_fc.csv')
df_group_diff = pd.read_csv(group_diff_file)
df_group_diff.sort_values(by='p_value', ascending=True)
# Out:
#                 ROI network1 network2  t_statistic   p_value  OCD_mean  \
# 758   ROI_21_ROI_30  Unknown  Unknown     2.665232  0.011466  0.557175
# 602   ROI_16_ROI_19  Unknown  Unknown     2.571591  0.013070  0.465421
# 784   ROI_22_ROI_30  Unknown  Unknown     2.580772  0.013525  0.625506
# 106    ROI_3_ROI_17  Unknown  Unknown     2.561757  0.013991  0.574754
# 1004  ROI_32_ROI_45  Unknown  Unknown     2.507248  0.016867  0.468452
# ...             ...      ...      ...          ...       ...       ...
# 833   ROI_24_ROI_30  Unknown  Unknown    -0.003440  0.997268  0.350428
# 213    ROI_5_ROI_37  Unknown  Unknown     0.003378  0.997321  0.245262
# 483   ROI_12_ROI_34  Unknown  Unknown     0.002609  0.997928  0.378208
# 1122  ROI_45_ROI_46  Unknown  Unknown     0.002248  0.998213  0.805749
# 1099  ROI_40_ROI_48  Unknown  Unknown     0.001953  0.998452  0.776637
#
#        HC_mean   OCD_std    HC_std  OCD_n  HC_n  cohens_d  p_corrected  \
# 758   0.436456  0.133695  0.199260     46    25  0.711477     0.998452
# 602   0.330724  0.214057  0.203489     46    25  0.644978     0.998452
# 784   0.527861  0.129374  0.159468     46    25  0.672474     0.998452
# 106   0.429284  0.202776  0.235500     46    25  0.661987     0.998452
# 1004  0.312681  0.182418  0.273662     46    25  0.669813     0.998452
# ...        ...       ...       ...    ...   ...       ...          ...
# 833   0.350605  0.212149  0.199956     46    25 -0.000862     0.998452
# 213   0.245109  0.156799  0.190100     46    25  0.000878     0.998452
# 483   0.378104  0.169402  0.152110     46    25  0.000649     0.998452
# 1122  0.805704  0.097222  0.067455     46    25  0.000537     0.998452
# 1099  0.776575  0.101740  0.136991     46    25  0.000515     0.998452
#
#       significant
# 758         False
# 602         False
# 784         False
# 106         False
# 1004        False
# ...           ...
# 833         False
# 213         False
# 483         False
# 1122        False
# 1099        False
#
# [1128 rows x 14 columns]

# %%
df_group_diff.loc[
    (df_group_diff['p_value'] <= 0.05)
]
# Out:
#                 ROI network1 network2  t_statistic   p_value  OCD_mean  \
# 106    ROI_3_ROI_17  Unknown  Unknown     2.561757  0.013991  0.574754
# 234    ROI_6_ROI_16  Unknown  Unknown     2.304944  0.026807  0.486624
# 329    ROI_8_ROI_30  Unknown  Unknown     2.013353  0.049821  0.443500
# 368    ROI_9_ROI_30  Unknown  Unknown     2.073111  0.042413  0.434128
# 370    ROI_9_ROI_32  Unknown  Unknown     2.168884  0.035830  0.432336
# 443   ROI_11_ROI_30  Unknown  Unknown     2.453699  0.018958  0.532031
# 514   ROI_13_ROI_30  Unknown  Unknown     2.053886  0.044718  0.378317
# 550   ROI_14_ROI_32  Unknown  Unknown     2.275538  0.026993  0.299448
# 602   ROI_16_ROI_19  Unknown  Unknown     2.571591  0.013070  0.465421
# 612   ROI_16_ROI_29  Unknown  Unknown     2.204091  0.032897  0.331437
# 633   ROI_17_ROI_19  Unknown  Unknown     2.263985  0.028623  0.508981
# 662   ROI_17_ROI_48  Unknown  Unknown    -2.042015  0.046539  0.522055
# 697   ROI_19_ROI_24  Unknown  Unknown     2.193223  0.033257  0.180686
# 709   ROI_19_ROI_36  Unknown  Unknown     2.208754  0.032286  0.207374
# 721   ROI_19_ROI_48  Unknown  Unknown     2.199127  0.033270  0.228078
# 749   ROI_20_ROI_48  Unknown  Unknown     2.189845  0.034141  0.319900
# 758   ROI_21_ROI_30  Unknown  Unknown     2.665232  0.011466  0.557175
# 784   ROI_22_ROI_30  Unknown  Unknown     2.580772  0.013525  0.625506
# 824   ROI_23_ROI_45  Unknown  Unknown     2.105920  0.040490  0.413596
# 848   ROI_24_ROI_45  Unknown  Unknown     2.230420  0.031345  0.465351
# 849   ROI_24_ROI_46  Unknown  Unknown     2.309627  0.026064  0.467055
# 850   ROI_24_ROI_47  Unknown  Unknown    -2.134628  0.036845  0.776962
# 897   ROI_27_ROI_28  Unknown  Unknown    -2.416936  0.018736  0.352416
# 929   ROI_28_ROI_40  Unknown  Unknown     2.123125  0.039854  0.347543
# 948   ROI_29_ROI_40  Unknown  Unknown     2.056685  0.046269  0.348457
# 1004  ROI_32_ROI_45  Unknown  Unknown     2.507248  0.016867  0.468452
# 1005  ROI_32_ROI_46  Unknown  Unknown     2.468459  0.018756  0.523164
# 1032  ROI_34_ROI_44  Unknown  Unknown    -2.133570  0.037565  0.302526
# 1058  ROI_36_ROI_45  Unknown  Unknown     2.090654  0.043166  0.457101
#
#        HC_mean   OCD_std    HC_std  OCD_n  HC_n  cohens_d  p_corrected  \
# 106   0.429284  0.202776  0.235500     46    25  0.661987     0.998452
# 234   0.368910  0.158951  0.221633     46    25  0.610374     0.998452
# 329   0.353781  0.170840  0.179144     46    25  0.512560     0.998452
# 368   0.337639  0.215473  0.165012     46    25  0.502790     0.998452
# 370   0.327077  0.168538  0.203416     46    25  0.563508     0.998452
# 443   0.412338  0.150085  0.212358     46    25  0.650943     0.998452
# 514   0.261517  0.246096  0.212872     46    25  0.507640     0.998452
# 550   0.190656  0.198683  0.183859     46    25  0.568357     0.998452
# 602   0.330724  0.214057  0.203489     46    25  0.644978     0.998452
# 612   0.217278  0.185121  0.214725     46    25  0.569460     0.998452
# 633   0.383195  0.199585  0.229871     46    25  0.584344     0.998452
# 662   0.591932  0.135634  0.135249     46    25 -0.515921     0.998452
# 697   0.046901  0.234355  0.244970     46    25  0.558086     0.998452
# 709   0.084857  0.206586  0.226011     46    25  0.565853     0.998452
# 721   0.112033  0.188679  0.218731     46    25  0.568133     0.998452
# 749   0.200968  0.189412  0.227282     46    25  0.568493     0.998452
# 758   0.436456  0.133695  0.199260     46    25  0.711477     0.998452
# 784   0.527861  0.129374  0.159468     46    25  0.672474     0.998452
# 824   0.309832  0.191295  0.196850     46    25  0.534610     0.998452
# 848   0.333599  0.198445  0.250479     46    25  0.583061     0.998452
# 849   0.332811  0.196749  0.245836     46    25  0.602939     0.998452
# 850   0.835119  0.125940  0.096720     46    25 -0.517936     0.998452
# 897   0.453876  0.191372  0.150868     46    25 -0.588810     0.998452
# 929   0.223974  0.197697  0.245872     46    25  0.553901     0.998452
# 948   0.232327  0.188401  0.239973     46    25  0.538301     0.998452
# 1004  0.312681  0.182418  0.273662     46    25  0.669813     0.998452
# 1005  0.385019  0.154296  0.249941     46    25  0.665122     0.998452
# 1032  0.397646  0.185742  0.171179     46    25 -0.532559     0.998452
# 1058  0.342404  0.177075  0.235612     46    25  0.550348     0.998452
#
#       significant
# 106         False
# 234         False
# 329         False
# 368         False
# 370         False
# 443         False
# 514         False
# 550         False
# 602         False
# 612         False
# 633         False
# 662         False
# 697         False
# 709         False
# 721         False
# 749         False
# 758         False
# 784         False
# 824         False
# 848         False
# 849         False
# 850         False
# 897         False
# 929         False
# 948         False
# 1004        False
# 1005        False
# 1032        False
# 1058        False

# %%
df_group_diff.loc[
    (df_group_diff['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_group_diff['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_group_diff['p_value'] <= 0.05)]
# Out:
# Empty DataFrame
# Columns: [ROI, network1, network2, t_statistic, p_value, OCD_mean, HC_mean, OCD_std, HC_std, OCD_n, HC_n, cohens_d, p_corrected, significant]
# Index: []

# %%
baselineFC_vs_deltaYBOCS_file = os.path.join(data_dir, 'baselineFC_vs_deltaYBOCS_harvard_oxford_cort-maxprob-thr25-2mm_roiroi_fc.csv')
df_baselineFC_vs_deltaYBOCS = pd.read_csv(baselineFC_vs_deltaYBOCS_file)
df_baselineFC_vs_deltaYBOCS.sort_values(by='fc_p_value', ascending=True).head(20)
# Out:
#                 ROI network1 network2  fc_effect  fc_p_value   r_value   n  \
# 332    ROI_8_ROI_33  Unknown  Unknown  -0.007919    0.005955 -0.410412  44
# 742   ROI_20_ROI_41  Unknown  Unknown  -0.013670    0.006195 -0.410720  44
# 278    ROI_7_ROI_19  Unknown  Unknown  -0.013439    0.011049 -0.383466  44
# 413   ROI_10_ROI_37  Unknown  Unknown   0.010404    0.011801  0.373898  44
# 677   ROI_18_ROI_33  Unknown  Unknown  -0.011722    0.020978 -0.352665  44
# 698   ROI_19_ROI_25  Unknown  Unknown  -0.014828    0.022055 -0.349998  44
# 557   ROI_14_ROI_39  Unknown  Unknown   0.010753    0.022305  0.348305  44
# 1091  ROI_39_ROI_48  Unknown  Unknown   0.008577    0.027188  0.318595  44
# 727   ROI_20_ROI_26  Unknown  Unknown  -0.013348    0.029300 -0.333903  44
# 699   ROI_19_ROI_26  Unknown  Unknown  -0.011102    0.033134 -0.327114  44
# 633   ROI_17_ROI_19  Unknown  Unknown  -0.010962    0.034952 -0.324238  44
# 1073  ROI_38_ROI_39  Unknown  Unknown   0.009672    0.036026  0.320383  44
# 317    ROI_8_ROI_18  Unknown  Unknown  -0.009425    0.036624 -0.319980  44
# 234    ROI_6_ROI_16  Unknown  Unknown  -0.008664    0.038174 -0.318729  44
# 296    ROI_7_ROI_37  Unknown  Unknown   0.010276    0.039220  0.314277  44
# 63     ROI_2_ROI_19  Unknown  Unknown  -0.007421    0.040365 -0.308517  44
# 260    ROI_6_ROI_42  Unknown  Unknown  -0.009428    0.043206 -0.302468  44
# 1063  ROI_37_ROI_39  Unknown  Unknown   0.009658    0.044000  0.306313  44
# 663   ROI_18_ROI_19  Unknown  Unknown  -0.007485    0.044540 -0.309834  44
# 318    ROI_8_ROI_19  Unknown  Unknown  -0.013609    0.044598 -0.309500  44
#
#                     condition_effects             condition_p_values  \
# 332    {'Wait': 0.013041021878648515}   {'Wait': 0.6775001709796773}
# 742    {'Wait': -0.06049138393499984}   {'Wait': 0.2693354872064561}
# 278    {'Wait': 0.007090007631967987}   {'Wait': 0.9026095878780158}
# 413   {'Wait': -0.039716312239316855}  {'Wait': 0.38283707362018504}
# 677   {'Wait': -0.030125199820342074}   {'Wait': 0.5914430718015421}
# 698   {'Wait': -0.041923044919904555}   {'Wait': 0.5584925823606868}
# 557     {'Wait': 0.06037281828140706}  {'Wait': 0.24911247917347393}
# 1091   {'Wait': -0.07417297819867777}  {'Wait': 0.08990084892327266}
# 727    {'Wait': -0.06791908584634537}  {'Wait': 0.31957732117454146}
# 699    {'Wait': -0.05292326643216243}   {'Wait': 0.3621615038770044}
# 633     {'Wait': -0.0362597822540601}   {'Wait': 0.5305172856203699}
# 1073    {'Wait': 0.07491850834094638}  {'Wait': 0.14856718764132987}
# 317    {'Wait': -0.06760946224979925}  {'Wait': 0.18160643715989003}
# 234    {'Wait': -0.04644740741662204}   {'Wait': 0.3199417811708492}
# 296   {'Wait': -0.014898925693144695}   {'Wait': 0.7879306278973528}
# 63     {'Wait': 0.030283569797377653}   {'Wait': 0.4530780365365017}
# 260     {'Wait': 0.04862569869950034}   {'Wait': 0.3509622520108392}
# 1063    {'Wait': 0.09922053205061823}  {'Wait': 0.06838270660778445}
# 663    {'Wait': -0.02959100059853588}   {'Wait': 0.4766238112553598}
# 318     {'Wait': -0.0740288222684196}  {'Wait': 0.32886334283563234}
#
#       model_r_squared  model_adj_r_squared  fc_p_value_fdr
# 332          0.171981             0.131590        0.999391
# 742          0.193360             0.154011        0.999391
# 278          0.147362             0.105770        0.999391
# 413          0.155822             0.114643        0.999391
# 677          0.130579             0.088168        0.999391
# 698          0.129884             0.087439        0.999391
# 557          0.149664             0.108184        0.999391
# 1091         0.163088             0.122263        0.999391
# 727          0.132959             0.090665        0.999391
# 699          0.125125             0.082448        0.999391
# 633          0.113780             0.070549        0.999391
# 1073         0.147708             0.106133        0.999391
# 317          0.141073             0.099174        0.999391
# 234          0.123263             0.080496        0.999391
# 296          0.100379             0.056495        0.999391
# 63           0.107672             0.064143        0.999391
# 260          0.110792             0.067416        0.999391
# 1063         0.165166             0.124443        0.999391
# 663          0.107233             0.063684        0.999391
# 318          0.116825             0.073743        0.999391

# %%
df_baselineFC_vs_deltaYBOCS.loc[
    (df_baselineFC_vs_deltaYBOCS['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_baselineFC_vs_deltaYBOCS['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_baselineFC_vs_deltaYBOCS['fc_p_value'] <= 0.05)
]
# Out:
# Empty DataFrame
# Columns: [ROI, network1, network2, fc_effect, fc_p_value, r_value, n, condition_effects, condition_p_values, model_r_squared, model_adj_r_squared, fc_p_value_fdr]
# Index: []

# %%
deltaFC_vs_deltaYBOCS_file = os.path.join(data_dir, 'deltaFC_vs_deltaYBOCS_harvard_oxford_cort-maxprob-thr25-2mm_roiroi_fc.csv')
df_deltaFC_vs_deltaYBOCS = pd.read_csv(deltaFC_vs_deltaYBOCS_file)
df_deltaFC_vs_deltaYBOCS.sort_values(by='fc_p_value', ascending=True).head(20)
# Out:
#                ROI network1 network2  fc_effect  fc_p_value   r_value   n  \
# 592  ROI_15_ROI_41  Unknown  Unknown  -0.013590    0.006591 -0.393906  43
# 446  ROI_11_ROI_33  Unknown  Unknown   0.013777    0.006720  0.410752  43
# 251   ROI_6_ROI_33  Unknown  Unknown   0.010606    0.007421  0.406027  43
# 602  ROI_16_ROI_19  Unknown  Unknown   0.014738    0.008721  0.397311  43
# 636  ROI_17_ROI_22  Unknown  Unknown   0.013315    0.015007  0.367194  43
# 684  ROI_18_ROI_40  Unknown  Unknown   0.013719    0.017429  0.361003  43
# 278   ROI_7_ROI_19  Unknown  Unknown   0.011651    0.023073  0.350614  43
# 231   ROI_6_ROI_13  Unknown  Unknown   0.011368    0.024738  0.342996  43
# 504  ROI_13_ROI_20  Unknown  Unknown   0.012130    0.027458  0.335325  43
# 503  ROI_13_ROI_19  Unknown  Unknown   0.012461    0.028608  0.338511  43
# 695  ROI_19_ROI_22  Unknown  Unknown   0.011553    0.037816  0.321966  43
# 123   ROI_3_ROI_34  Unknown  Unknown  -0.014174    0.040217 -0.318834  43
# 666  ROI_18_ROI_22  Unknown  Unknown   0.011254    0.040285  0.307999  43
# 73    ROI_2_ROI_29  Unknown  Unknown  -0.006230    0.041051 -0.316367  43
# 225    ROI_6_ROI_7  Unknown  Unknown   0.009356    0.042355  0.312851  43
# 978  ROI_31_ROI_35  Unknown  Unknown   0.010534    0.044922  0.298788  43
# 515  ROI_13_ROI_31  Unknown  Unknown  -0.012787    0.048983 -0.302754  43
# 431  ROI_11_ROI_18  Unknown  Unknown   0.014952    0.049325  0.304500  43
# 810  ROI_23_ROI_31  Unknown  Unknown  -0.010633    0.050245 -0.304595  43
# 861  ROI_25_ROI_35  Unknown  Unknown   0.011339    0.050421  0.298779  43
#
#                    condition_effects             condition_p_values  \
# 592    {'Wait': 0.09924247079798365}  {'Wait': 0.07656365595489045}
# 446  {'Wait': -0.016237312454041017}   {'Wait': 0.7713165329783314}
# 251    {'Wait': 0.04595775998974473}   {'Wait': 0.2948159295067785}
# 602  {'Wait': -0.030082362140375084}   {'Wait': 0.6275608307905975}
# 636  {'Wait': -0.052322916724006935}    {'Wait': 0.390861705534559}
# 684    {'Wait': -0.0444476854136931}  {'Wait': 0.48927024383406215}
# 278    {'Wait': 0.03898075651296331}   {'Wait': 0.4962787606558243}
# 231   {'Wait': -0.03261755345802089}   {'Wait': 0.5641806385644057}
# 504  {'Wait': -0.048498017881622946}   {'Wait': 0.4314845438005622}
# 503   {'Wait': 0.047184932027891646}   {'Wait': 0.4595429520423985}
# 695    {'Wait': 0.05484604599214621}   {'Wait': 0.3811054837632325}
# 123   {'Wait': -0.03885309781824932}    {'Wait': 0.616458781496992}
# 666   {'Wait': -0.07702442255858441}   {'Wait': 0.2149696270960559}
# 73   {'Wait': 0.0032326960545173977}   {'Wait': 0.9246735185978622}
# 225  {'Wait': -0.020570889950762505}   {'Wait': 0.6909671029725633}
# 978   {'Wait': -0.08606673697889793}  {'Wait': 0.14964229174444013}
# 515   {'Wait': 0.040333552008816866}    {'Wait': 0.581143891146415}
# 431  {'Wait': -0.016991564461842648}   {'Wait': 0.8424220973517711}
# 810  {'Wait': -0.054367274574588634}   {'Wait': 0.3753407559914945}
# 861  {'Wait': -0.052997712477390345}     {'Wait': 0.41772383380668}
#
#      model_r_squared  model_adj_r_squared  fc_p_value_fdr
# 592         0.219640             0.180622        0.999136
# 446         0.170493             0.129017        0.999136
# 251         0.187740             0.147127        0.999136
# 602         0.162859             0.121002        0.999136
# 636         0.150807             0.108347        0.999136
# 684         0.140786             0.097825        0.999136
# 278         0.133147             0.089804        0.999136
# 231         0.125042             0.081294        0.999136
# 504         0.126238             0.082550        0.999136
# 503         0.126766             0.083104        0.999136
# 695         0.120900             0.076946        0.999136
# 123         0.107342             0.062710        0.999136
# 666         0.129417             0.085888        0.999136
# 73          0.100292             0.055306        0.999136
# 225         0.101478             0.056552        0.999136
# 978         0.135895             0.092690        0.999136
# 515         0.098632             0.053564        0.999136
# 431         0.093628             0.048309        0.999136
# 810         0.110649             0.066181        0.999136
# 861         0.104284             0.059498        0.999136

# %%
df_deltaFC_vs_deltaYBOCS.loc[
    (df_deltaFC_vs_deltaYBOCS['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_deltaFC_vs_deltaYBOCS['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_deltaFC_vs_deltaYBOCS['fc_p_value'] <= 0.05)
]
# Out:
# Empty DataFrame
# Columns: [ROI, network1, network2, fc_effect, fc_p_value, r_value, n, condition_effects, condition_p_values, model_r_squared, model_adj_r_squared, fc_p_value_fdr]
# Index: []

# %%
condition_baseline_FC_file = os.path.join(data_dir, 'condition_baseline_FC_harvard_oxford_cort-maxprob-thr25-2mm_roiroi_fc.csv')
condition_baseline_FC = pd.read_csv(condition_baseline_FC_file)
condition_baseline_FC.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                 ROI network1 network2 reference_condition  \
# 1112  ROI_42_ROI_48  Unknown  Unknown               Treat
# 71     ROI_2_ROI_27  Unknown  Unknown               Treat
# 52      ROI_2_ROI_8  Unknown  Unknown               Treat
# 455   ROI_11_ROI_42  Unknown  Unknown               Treat
# 618   ROI_16_ROI_35  Unknown  Unknown               Treat
# 328    ROI_8_ROI_29  Unknown  Unknown               Treat
# 162    ROI_4_ROI_29  Unknown  Unknown               Treat
# 1074  ROI_38_ROI_40  Unknown  Unknown               Treat
# 1055  ROI_36_ROI_42  Unknown  Unknown               Treat
# 367    ROI_9_ROI_29  Unknown  Unknown               Treat
# 405   ROI_10_ROI_29  Unknown  Unknown               Treat
# 818   ROI_23_ROI_39  Unknown  Unknown               Treat
# 1043  ROI_35_ROI_42  Unknown  Unknown               Treat
# 58     ROI_2_ROI_14  Unknown  Unknown               Treat
# 910   ROI_27_ROI_41  Unknown  Unknown               Treat
# 245    ROI_6_ROI_27  Unknown  Unknown               Treat
# 247    ROI_6_ROI_29  Unknown  Unknown               Treat
# 92     ROI_2_ROI_48  Unknown  Unknown               Treat
# 55     ROI_2_ROI_11  Unknown  Unknown               Treat
# 418   ROI_10_ROI_42  Unknown  Unknown               Treat
#
#      comparison_condition  t_statistic   p_value  reference_mean  \
# 1112                 Wait    -3.409747  0.001415        0.466807
# 71                   Wait    -3.282095  0.002023        0.267056
# 52                   Wait    -3.195250  0.002704        0.538500
# 455                  Wait    -3.020547  0.004524        0.246837
# 618                  Wait    -2.966136  0.005016        0.331232
# 328                  Wait    -2.909545  0.005960        0.572806
# 162                  Wait    -2.865663  0.006559        0.478652
# 1074                 Wait     2.825143  0.007153        0.323324
# 1055                 Wait    -2.746325  0.008730        0.484831
# 367                  Wait    -2.732283  0.009121        0.480029
# 405                  Wait    -2.688539  0.010167        0.510618
# 818                  Wait    -2.696357  0.010252        0.737396
# 1043                 Wait    -2.643654  0.011361        0.244523
# 58                   Wait    -2.650773  0.011372        0.323712
# 910                  Wait    -2.631524  0.011963        0.069804
# 245                  Wait    -2.574771  0.013490        0.126280
# 247                  Wait    -2.623421  0.013528        0.534217
# 92                   Wait    -2.574421  0.013543        0.394027
# 55                   Wait    -2.560301  0.014006        0.209398
# 418                  Wait    -2.539701  0.014787        0.514644
#
#       comparison_mean  reference_n  comparison_n  effect_size  p_value_fdr
# 1112         0.312292           24            22    -1.029743     0.766025
# 71           0.093991           24            22    -0.988502     0.766025
# 52           0.385055           24            22    -0.968826     0.766025
# 455          0.052940           24            22    -0.918485     0.766025
# 618          0.181762           24            22    -0.899008     0.766025
# 328          0.429921           24            22    -0.883670     0.766025
# 162          0.277999           24            22    -0.868798     0.766025
# 1074         0.467592           24            22     0.847684     0.766025
# 1055         0.342147           24            22    -0.829179     0.766025
# 367          0.319616           24            22    -0.826432     0.766025
# 405          0.363198           24            22    -0.812567     0.766025
# 818          0.659823           24            22    -0.818431     0.766025
# 1043         0.086705           24            22    -0.798224     0.766025
# 58           0.213367           24            22    -0.803460     0.766025
# 910         -0.077721           24            22    -0.797891     0.766025
# 245         -0.024489           24            22    -0.776777     0.766025
# 247          0.361503           24            22    -0.802602     0.766025
# 92           0.270584           24            22    -0.777676     0.766025
# 55           0.036006           24            22    -0.772957     0.766025
# 418          0.362744           24            22    -0.767552     0.766025

# %%
condition_followup_FC_file = os.path.join(data_dir, 'condition_followup_FC_harvard_oxford_cort-maxprob-thr25-2mm_roiroi_fc.csv')
condition_followup_FC = pd.read_csv(condition_followup_FC_file)
condition_followup_FC.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                 ROI network1 network2 reference_condition  \
# 1112  ROI_42_ROI_48  Unknown  Unknown               Treat
# 920   ROI_28_ROI_31  Unknown  Unknown               Treat
# 412   ROI_10_ROI_36  Unknown  Unknown               Treat
# 822   ROI_23_ROI_43  Unknown  Unknown               Treat
# 821   ROI_23_ROI_42  Unknown  Unknown               Treat
# 825   ROI_23_ROI_46  Unknown  Unknown               Treat
# 1093  ROI_40_ROI_42  Unknown  Unknown               Treat
# 1126  ROI_46_ROI_48  Unknown  Unknown               Treat
# 1094  ROI_40_ROI_43  Unknown  Unknown               Treat
# 871   ROI_25_ROI_45  Unknown  Unknown               Treat
# 1121  ROI_44_ROI_48  Unknown  Unknown               Treat
# 1086  ROI_39_ROI_43  Unknown  Unknown               Treat
# 92     ROI_2_ROI_48  Unknown  Unknown               Treat
# 424   ROI_10_ROI_48  Unknown  Unknown               Treat
# 838   ROI_24_ROI_35  Unknown  Unknown               Treat
# 418   ROI_10_ROI_42  Unknown  Unknown               Treat
# 1052  ROI_36_ROI_39  Unknown  Unknown               Treat
# 1078  ROI_38_ROI_44  Unknown  Unknown               Treat
# 1124  ROI_45_ROI_48  Unknown  Unknown               Treat
# 374    ROI_9_ROI_36  Unknown  Unknown               Treat
#
#      comparison_condition  t_statistic   p_value  reference_mean  \
# 1112                 Wait    -2.898172  0.006287        0.448381
# 920                  Wait    -2.843377  0.007043        0.580373
# 412                  Wait    -2.715189  0.009720        0.568974
# 822                  Wait    -2.696295  0.010130        0.563702
# 821                  Wait    -2.689782  0.010880        0.555678
# 825                  Wait    -2.656623  0.011197        0.586811
# 1093                 Wait    -2.611866  0.013015        0.463904
# 1126                 Wait    -2.591366  0.013192        0.512554
# 1094                 Wait    -2.595613  0.013497        0.461083
# 871                  Wait    -2.545173  0.014823        0.295796
# 1121                 Wait    -2.556952  0.015082        0.370634
# 1086                 Wait    -2.500143  0.016669        0.467087
# 92                   Wait    -2.479468  0.017619        0.345913
# 424                  Wait    -2.466268  0.018058        0.529063
# 838                  Wait    -2.398991  0.021086        0.427034
# 418                  Wait    -2.407166  0.021180        0.490423
# 1052                 Wait    -2.394493  0.021728        0.706728
# 1078                 Wait    -2.388390  0.022262        0.433352
# 1124                 Wait    -2.369070  0.022688        0.461765
# 374                  Wait    -2.357699  0.023647        0.495773
#
#       comparison_mean  reference_n  comparison_n  effect_size  p_value_fdr
# 1112         0.253349           21            22    -0.901284     0.828755
# 920          0.460496           21            22    -0.885670     0.828755
# 412          0.414464           21            22    -0.846320     0.828755
# 822          0.448930           21            22    -0.842326     0.828755
# 821          0.421965           21            22    -0.835695     0.828755
# 825          0.480967           21            22    -0.829818     0.828755
# 1093         0.314027           21            22    -0.812015     0.828755
# 1126         0.365784           21            22    -0.809640     0.828755
# 1094         0.314143           21            22    -0.807130     0.828755
# 871          0.168234           21            22    -0.793756     0.828755
# 1121         0.212775           21            22    -0.794338     0.828755
# 1086         0.335453           21            22    -0.778841     0.828755
# 92           0.169872           21            22    -0.771948     0.828755
# 424          0.395634           21            22    -0.768487     0.828755
# 838          0.313539           21            22    -0.748594     0.828755
# 418          0.333333           21            22    -0.748662     0.828755
# 1052         0.622573           21            22    -0.744996     0.828755
# 1078         0.276327           21            22    -0.742491     0.828755
# 1124         0.340537           21            22    -0.740770     0.828755
# 374          0.372838           21            22    -0.738760     0.828755

# %%
condition_FC_change_file = os.path.join(data_dir, 'condition_FC_change_harvard_oxford_cort-maxprob-thr25-2mm_roiroi_fc.csv')
condition_FC_change = pd.read_csv(condition_FC_change_file)
condition_FC_change.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                 ROI network1 network2 reference_condition  \
# 162    ROI_4_ROI_29  Unknown  Unknown               Treat
# 792   ROI_22_ROI_38  Unknown  Unknown               Treat
# 1038  ROI_35_ROI_37  Unknown  Unknown               Treat
# 205    ROI_5_ROI_29  Unknown  Unknown               Treat
# 36     ROI_1_ROI_38  Unknown  Unknown               Treat
# 239    ROI_6_ROI_21  Unknown  Unknown               Treat
# 839   ROI_24_ROI_36  Unknown  Unknown               Treat
# 1126  ROI_46_ROI_48  Unknown  Unknown               Treat
# 3       ROI_1_ROI_5  Unknown  Unknown               Treat
# 161    ROI_4_ROI_28  Unknown  Unknown               Treat
# 27     ROI_1_ROI_29  Unknown  Unknown               Treat
# 682   ROI_18_ROI_38  Unknown  Unknown               Treat
# 621   ROI_16_ROI_38  Unknown  Unknown               Treat
# 416   ROI_10_ROI_40  Unknown  Unknown               Treat
# 118    ROI_3_ROI_29  Unknown  Unknown               Treat
# 203    ROI_5_ROI_27  Unknown  Unknown               Treat
# 47      ROI_2_ROI_3  Unknown  Unknown               Treat
# 412   ROI_10_ROI_36  Unknown  Unknown               Treat
# 1078  ROI_38_ROI_44  Unknown  Unknown               Treat
# 601   ROI_16_ROI_18  Unknown  Unknown               Treat
#
#      comparison_condition  t_statistic   p_value  reference_mean  \
# 162                  Wait     2.871134  0.006450       -0.178753
# 792                  Wait    -2.864451  0.006958        0.045579
# 1038                 Wait     2.741290  0.009985       -0.118476
# 205                  Wait     2.646270  0.011694       -0.164011
# 36                   Wait    -2.604599  0.012785        0.051989
# 239                  Wait     2.503769  0.016604       -0.064317
# 839                  Wait     2.522274  0.017180       -0.063689
# 1126                 Wait    -2.431444  0.020011        0.010799
# 3                    Wait     2.434136  0.020115       -0.086649
# 161                  Wait     2.433413  0.020223       -0.103708
# 27                   Wait     2.388621  0.022105       -0.121114
# 682                  Wait    -2.367079  0.022966        0.046697
# 621                  Wait    -2.359012  0.023188        0.071779
# 416                  Wait    -2.334113  0.024590        0.084970
# 118                  Wait     2.307670  0.026225       -0.146973
# 203                  Wait     2.294650  0.026946       -0.052665
# 47                   Wait     2.274801  0.028279       -0.148200
# 412                  Wait    -2.259812  0.029273        0.053172
# 1078                 Wait    -2.238947  0.030651        0.082034
# 601                  Wait    -2.245088  0.030801        0.033894
#
#       comparison_mean  reference_n  comparison_n  effect_size  p_value_fdr
# 162          0.039408           21            22     0.897040     0.998323
# 792         -0.096257           21            22    -0.898686     0.998323
# 1038         0.026695           21            22     0.861726     0.998323
# 205          0.018460           21            22     0.823925     0.998323
# 36          -0.117594           21            22    -0.814167     0.998323
# 239          0.033569           21            22     0.779560     0.998323
# 839          0.030055           21            22     0.793431     0.998323
# 1126        -0.112671           21            22    -0.762321     0.998323
# 3            0.050425           21            22     0.756395     0.998323
# 161          0.040729           21            22     0.755995     0.998323
# 27          -0.002482           21            22     0.742949     0.998323
# 682         -0.112671           21            22    -0.741093     0.998323
# 621         -0.056683           21            22    -0.737157     0.998323
# 416         -0.023506           21            22    -0.729395     0.998323
# 118         -0.011754           21            22     0.721697     0.998323
# 203          0.089367           21            22     0.716463     0.998323
# 47           0.013765           21            22     0.709393     0.998323
# 412         -0.045029           21            22    -0.706550     0.998323
# 1078        -0.084186           21            22    -0.698930     0.998323
# 601         -0.121604           21            22    -0.698305     0.998323

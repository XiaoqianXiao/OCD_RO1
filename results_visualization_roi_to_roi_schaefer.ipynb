# %%
import pandas as pd
import numpy as np
import os
import glob
import os
import subprocess
import pandas as pd
import numpy as np
from scipy.stats import iqr
from statsmodels.formula.api import ols
from scipy.stats import zscore
from nipype.interfaces.fsl import ImageMaths
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import pandas as pd
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests
# Create bar plot
plt.style.use('seaborn-v0_8-poster')
#plt.style.use('seaborn-v0_8')
fontsize = 11
plt.rcParams.update({
    "font.size": fontsize,          # Global font size
    "axes.labelsize": fontsize,     # X and Y axis labels
    "axes.titlesize": fontsize,     # Title (if used)
    "xtick.labelsize": fontsize,    # X-axis tick labels
    "ytick.labelsize": fontsize,    # Y-axis tick labels
    "legend.fontsize": fontsize,    # Legend font size
})

# %%
project_dir = '/Users/xiaoqianxiao/projects/OCD'
data_dir = os.path.join(project_dir, 'results/NW_group_roi_roi')
result_dir = os.path.join(project_dir, 'results/visualization/NW_group_roi_roi')
if not os.path.exists(result_dir):
    os.makedirs(result_dir, exist_ok=True)

# %%
group_diff_file = os.path.join(data_dir, 'group_diff_baseline_schaefer_2018_100_7_2_roi_network_fc.csv')
df_group_diff = pd.read_csv(group_diff_file)
df_group_diff.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                           ROI           network1           network2  \
# 245            ROI_36_Default   Dorsal Attention            Default
# 252            ROI_37_Default   Dorsal Attention            Default
# 257  ROI_37_Ventral Attention   Dorsal Attention  Ventral Attention
# 250  ROI_36_Ventral Attention   Dorsal Attention  Ventral Attention
# 258             ROI_37_Visual   Dorsal Attention             Visual
# 56              ROI_9_Default             Visual            Default
# 469            ROI_68_Default             Limbic            Default
# 448            ROI_65_Default             Limbic            Default
# 680   ROI_98_Dorsal Attention            Default   Dorsal Attention
# 476            ROI_69_Default             Limbic            Default
# 682             ROI_98_Limbic            Default             Limbic
# 140            ROI_21_Default        Somatomotor            Default
# 253   ROI_37_Dorsal Attention   Dorsal Attention   Dorsal Attention
# 607  ROI_87_Ventral Attention            Default  Ventral Attention
# 685             ROI_98_Visual            Default             Visual
# 591             ROI_85_Limbic            Default             Limbic
# 21              ROI_4_Default             Visual            Default
# 45               ROI_7_Limbic             Visual             Limbic
# 380     ROI_55_Frontoparietal  Ventral Attention     Frontoparietal
# 387     ROI_56_Frontoparietal  Ventral Attention     Frontoparietal
#
#      t_statistic   p_value  OCD_mean   HC_mean  OCD_n  HC_n  p_value_fdr
# 245     2.690533  0.009775  0.369085  0.285704     46    46      0.87739
# 252     2.657911  0.010802  0.421368  0.341704     46    46      0.87739
# 257     2.351884  0.022753  0.345546  0.264878     46    46      0.87739
# 250     2.341885  0.023324  0.333935  0.252170     46    46      0.87739
# 258     2.250032  0.028715  0.247801  0.160700     46    46      0.87739
# 56      2.232091  0.031427  0.378983  0.287305     46    46      0.87739
# 469     2.174688  0.034541  0.205946  0.102173     46    46      0.87739
# 448     2.151814  0.036393  0.318233  0.229128     46    46      0.87739
# 680     2.106536  0.040615  0.348873  0.275509     46    46      0.87739
# 476     2.081982  0.042875  0.304489  0.210640     46    46      0.87739
# 682     2.002704  0.051516  0.294409  0.194900     46    46      0.87739
# 140     1.969893  0.055131  0.304357  0.216623     46    46      0.87739
# 253     1.957296  0.055813  0.338961  0.282848     46    46      0.87739
# 607     1.940743  0.058084  0.304674  0.233136     46    46      0.87739
# 685     1.941191  0.059412  0.275255  0.186178     46    46      0.87739
# 591     1.886851  0.065573  0.323161  0.233610     46    46      0.87739
# 21      1.880801  0.065630  0.317064  0.241099     46    46      0.87739
# 45      1.882244  0.065830  0.449715  0.394748     46    46      0.87739
# 380     1.865953  0.068284  0.283520  0.207552     46    46      0.87739
# 387     1.870669  0.068737  0.281712  0.206772     46    46      0.87739

# %%
df_group_diff.loc[
    (df_group_diff['p_value'] <= 0.05)
]
# Out:
#                           ROI          network1           network2  \
# 56              ROI_9_Default            Visual            Default
# 245            ROI_36_Default  Dorsal Attention            Default
# 250  ROI_36_Ventral Attention  Dorsal Attention  Ventral Attention
# 252            ROI_37_Default  Dorsal Attention            Default
# 257  ROI_37_Ventral Attention  Dorsal Attention  Ventral Attention
# 258             ROI_37_Visual  Dorsal Attention             Visual
# 448            ROI_65_Default            Limbic            Default
# 469            ROI_68_Default            Limbic            Default
# 476            ROI_69_Default            Limbic            Default
# 680   ROI_98_Dorsal Attention           Default   Dorsal Attention
#
#      t_statistic   p_value  OCD_mean   HC_mean  OCD_n  HC_n  p_value_fdr
# 56      2.232091  0.031427  0.378983  0.287305     46    46      0.87739
# 245     2.690533  0.009775  0.369085  0.285704     46    46      0.87739
# 250     2.341885  0.023324  0.333935  0.252170     46    46      0.87739
# 252     2.657911  0.010802  0.421368  0.341704     46    46      0.87739
# 257     2.351884  0.022753  0.345546  0.264878     46    46      0.87739
# 258     2.250032  0.028715  0.247801  0.160700     46    46      0.87739
# 448     2.151814  0.036393  0.318233  0.229128     46    46      0.87739
# 469     2.174688  0.034541  0.205946  0.102173     46    46      0.87739
# 476     2.081982  0.042875  0.304489  0.210640     46    46      0.87739
# 680     2.106536  0.040615  0.348873  0.275509     46    46      0.87739

# %%
df_group_diff.loc[
    (df_group_diff['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_group_diff['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_group_diff['p_value'] <= 0.05)]
# Out:
#                          ROI          network1          network2  t_statistic  \
# 245           ROI_36_Default  Dorsal Attention           Default     2.690533
# 252           ROI_37_Default  Dorsal Attention           Default     2.657911
# 680  ROI_98_Dorsal Attention           Default  Dorsal Attention     2.106536
#
#       p_value  OCD_mean   HC_mean  OCD_n  HC_n  p_value_fdr
# 245  0.009775  0.369085  0.285704     46    46      0.87739
# 252  0.010802  0.421368  0.341704     46    46      0.87739
# 680  0.040615  0.348873  0.275509     46    46      0.87739

# %%
baselineFC_vs_deltaYBOCS_file = os.path.join(data_dir, 'baselineFC_vs_deltaYBOCS_schaefer_2018_100_7_2_roi_network_fc.csv')
df_baselineFC_vs_deltaYBOCS = pd.read_csv(baselineFC_vs_deltaYBOCS_file)
df_baselineFC_vs_deltaYBOCS.sort_values(by='fc_p_value', ascending=True).head(20)
# Out:
#                           ROI           network1           network2  \
# 677  ROI_97_Ventral Attention            Default  Ventral Attention
# 468             ROI_67_Visual             Limbic             Visual
# 562     ROI_81_Frontoparietal     Frontoparietal     Frontoparietal
# 298        ROI_43_Somatomotor  Ventral Attention        Somatomotor
# 563             ROI_81_Limbic     Frontoparietal             Limbic
# 564        ROI_81_Somatomotor     Frontoparietal        Somatomotor
# 238            ROI_35_Default   Dorsal Attention            Default
# 179        ROI_26_Somatomotor        Somatomotor        Somatomotor
# 339             ROI_49_Limbic  Ventral Attention             Limbic
# 197   ROI_29_Dorsal Attention   Dorsal Attention   Dorsal Attention
# 362  ROI_52_Ventral Attention  Ventral Attention  Ventral Attention
# 356             ROI_51_Visual  Ventral Attention             Visual
# 163     ROI_24_Frontoparietal        Somatomotor     Frontoparietal
# 559             ROI_80_Visual     Frontoparietal             Visual
# 388             ROI_56_Limbic  Ventral Attention             Limbic
# 165        ROI_24_Somatomotor        Somatomotor        Somatomotor
# 650             ROI_93_Visual            Default             Visual
# 517             ROI_74_Visual     Frontoparietal             Visual
# 214        ROI_31_Somatomotor   Dorsal Attention        Somatomotor
# 291        ROI_42_Somatomotor   Dorsal Attention        Somatomotor
#
#      fc_effect  fc_p_value   r_value   n                condition_effects  \
# 677   0.005091    0.065873  0.276675  44  {'Wait': -0.026432557736780965}
# 468   0.006041    0.067677  0.278170  44  {'Wait': -0.018394069831129924}
# 562  -0.006040    0.070899 -0.277818  44  {'Wait': 0.0036019455173979843}
# 298  -0.006497    0.092000 -0.261653  44   {'Wait': -0.05974194784569047}
# 563  -0.007722    0.093952 -0.256089  44    {'Wait': 0.02228537039395257}
# 564  -0.007152    0.096053 -0.257791  44  {'Wait': -0.005518719119997344}
# 238   0.008302    0.097253  0.239226  44   {'Wait': -0.09760696338193625}
# 179  -0.004951    0.113761 -0.246254  44  {'Wait': -0.052333551260151226}
# 339   0.006305    0.118076  0.227105  44   {'Wait': -0.07251198001304636}
# 197  -0.006957    0.123004 -0.241318  44  {'Wait': -0.042244389030526325}
# 362   0.005661    0.132055  0.235936  44    {'Wait': 0.03669131786386686}
# 356   0.004562    0.133431  0.227216  44  {'Wait': -0.026004309941473135}
# 163  -0.004147    0.145538 -0.227921  44    {'Wait': -0.0459946911987166}
# 559   0.004708    0.146373  0.227906  44    {'Wait': 0.03015289860722919}
# 388   0.004958    0.148344  0.201542  44   {'Wait': -0.08520322347852942}
# 165  -0.004245    0.155729 -0.221846  44   {'Wait': -0.05813891069198469}
# 650   0.004981    0.157851  0.209610  44   {'Wait': -0.04734542117383837}
# 517   0.005453    0.160858  0.213872  44   {'Wait': -0.02565353380326137}
# 214  -0.005376    0.161694 -0.218098  44   {'Wait': -0.08415785123754518}
# 291  -0.005725    0.162223 -0.219737  44   {'Wait': -0.04073054894736537}
#
#                  condition_p_values  model_r_squared  model_adj_r_squared  \
# 677   {'Wait': 0.39461679570629515}         0.092924             0.048676
# 468     {'Wait': 0.619035578809185}         0.082993             0.038261
# 562    {'Wait': 0.9232407666621248}         0.077395             0.032389
# 298   {'Wait': 0.17175129084680912}         0.110438             0.067045
# 563    {'Wait': 0.6666440948267234}         0.069853             0.024479
# 564    {'Wait': 0.9088173849333774}         0.066758             0.021234
# 238    {'Wait': 0.0876860166475618}         0.122721             0.079927
# 179    {'Wait': 0.1418911445007774}         0.109363             0.065917
# 339    {'Wait': 0.1151147309982089}         0.107959             0.064445
# 197   {'Wait': 0.40670038711930645}         0.074106             0.028940
# 362   {'Wait': 0.38764298932806485}         0.072907             0.027683
# 356    {'Wait': 0.4485529020007438}         0.064979             0.019369
# 163   {'Wait': 0.15668668021352306}         0.097754             0.053742
# 559   {'Wait': 0.41060987874741584}         0.067657             0.022176
# 388   {'Wait': 0.03203845670420226}         0.143532             0.101753
# 165   {'Wait': 0.08999781440425708}         0.114348             0.071145
# 650    {'Wait': 0.2374472892265876}         0.076319             0.031261
# 517    {'Wait': 0.5590844584691159}         0.053748             0.007590
# 214  {'Wait': 0.057297155680866026}         0.128861             0.086366
# 291    {'Wait': 0.3798429511352601}         0.066234             0.020684
#
#      fc_p_value_fdr
# 677        0.998662
# 468        0.998662
# 562        0.998662
# 298        0.998662
# 563        0.998662
# 564        0.998662
# 238        0.998662
# 179        0.998662
# 339        0.998662
# 197        0.998662
# 362        0.998662
# 356        0.998662
# 163        0.998662
# 559        0.998662
# 388        0.998662
# 165        0.998662
# 650        0.998662
# 517        0.998662
# 214        0.998662
# 291        0.998662

# %%
df_baselineFC_vs_deltaYBOCS.loc[
    (df_baselineFC_vs_deltaYBOCS['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_baselineFC_vs_deltaYBOCS['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_baselineFC_vs_deltaYBOCS['fc_p_value'] <= 0.05)
]
# Out:
# Empty DataFrame
# Columns: [ROI, network1, network2, fc_effect, fc_p_value, r_value, n, condition_effects, condition_p_values, model_r_squared, model_adj_r_squared, fc_p_value_fdr]
# Index: []

# %%
deltaFC_vs_deltaYBOCS_file = os.path.join(data_dir, 'deltaFC_vs_deltaYBOCS_schaefer_2018_100_7_2_roi_network_fc.csv')
df_deltaFC_vs_deltaYBOCS = pd.read_csv(deltaFC_vs_deltaYBOCS_file)
df_deltaFC_vs_deltaYBOCS.sort_values(by='fc_p_value', ascending=True).head(20)
# Out:
#                           ROI           network1           network2  \
# 567            ROI_82_Default     Frontoparietal            Default
# 450     ROI_65_Frontoparietal             Limbic     Frontoparietal
# 273            ROI_40_Default   Dorsal Attention            Default
# 486             ROI_70_Limbic             Limbic             Limbic
# 4           ROI_1_Somatomotor             Visual        Somatomotor
# 452        ROI_65_Somatomotor             Limbic        Somatomotor
# 569     ROI_82_Frontoparietal     Frontoparietal     Frontoparietal
# 603   ROI_87_Dorsal Attention            Default   Dorsal Attention
# 562     ROI_81_Frontoparietal     Frontoparietal     Frontoparietal
# 271  ROI_39_Ventral Attention   Dorsal Attention  Ventral Attention
# 570             ROI_82_Limbic     Frontoparietal             Limbic
# 436     ROI_63_Frontoparietal             Limbic     Frontoparietal
# 677  ROI_97_Ventral Attention            Default  Ventral Attention
# 560            ROI_81_Default     Frontoparietal            Default
# 334  ROI_48_Ventral Attention  Ventral Attention  Ventral Attention
# 607  ROI_87_Ventral Attention            Default  Ventral Attention
# 449   ROI_65_Dorsal Attention             Limbic   Dorsal Attention
# 266            ROI_39_Default   Dorsal Attention            Default
# 438        ROI_63_Somatomotor             Limbic        Somatomotor
# 563             ROI_81_Limbic     Frontoparietal             Limbic
#
#      fc_effect  fc_p_value   r_value   n                 condition_effects  \
# 567   0.007698    0.014693  0.374719  43    {'Wait': 0.017901222511456913}
# 450   0.008301    0.018239  0.363029  43    {'Wait': 0.030166693538886423}
# 273  -0.009906    0.022464 -0.343851  43    {'Wait': 0.050623609883329986}
# 486   0.007481    0.023501  0.349595  43     {'Wait': 0.00696598535993259}
# 4     0.008698    0.029140  0.334503  43    {'Wait': -0.02113278252535137}
# 452   0.007366    0.037558  0.322493  43    {'Wait': 0.005012882927281441}
# 569   0.008842    0.039184  0.320234  43    {'Wait': 0.012739249905786128}
# 603  -0.006635    0.039749 -0.313745  43    {'Wait': 0.028332498747318954}
# 562   0.005472    0.045121  0.311760  43     {'Wait': 0.01863924615033402}
# 271  -0.007607    0.047916 -0.307009  43    {'Wait': 0.001882209305586035}
# 570   0.009293    0.048572  0.306714  43    {'Wait': 0.006755599389664906}
# 436   0.008248    0.053387  0.301041  43     {'Wait': 0.03653878197916646}
# 677  -0.006330    0.056607 -0.290156  43     {'Wait': 0.03529810519484631}
# 560   0.006770    0.057006  0.296925  43     {'Wait': 0.02811409201262578}
# 334  -0.005705    0.058066 -0.295798  43   {'Wait': -0.021525041004726533}
# 607  -0.007802    0.065469 -0.286169  43     {'Wait': 0.00899803352547602}
# 449   0.007645    0.067083  0.285052  43   {'Wait': -0.003512426406787745}
# 266  -0.007021    0.068689 -0.270718  43     {'Wait': 0.06701240712076104}
# 438   0.007862    0.070536  0.280530  43   {'Wait': -0.015026983121541526}
# 563   0.007169    0.078823  0.274326  43  {'Wait': -7.324534103360716e-05}
#
#                 condition_p_values  model_r_squared  model_adj_r_squared  \
# 567   {'Wait': 0.6093536177792264}         0.146077             0.103381
# 450   {'Wait': 0.4417747153413534}         0.144697             0.101932
# 273   {'Wait': 0.2982698778892731}         0.142055             0.099158
# 486   {'Wait': 0.8499139683074631}         0.123012             0.079163
# 4     {'Wait': 0.6356239715901629}         0.116925             0.072771
# 452   {'Wait': 0.8994620973702925}         0.104364             0.059582
# 569   {'Wait': 0.7910055988197442}         0.104144             0.059351
# 603  {'Wait': 0.43511709466541615}         0.112231             0.067843
# 562    {'Wait': 0.544117646171973}         0.105565             0.060843
# 271   {'Wait': 0.9652388563459993}         0.094298             0.049013
# 570   {'Wait': 0.8984365555810316}         0.094447             0.049169
# 436   {'Wait': 0.4482794306716984}         0.103766             0.058955
# 677  {'Wait': 0.34745940949515874}         0.104427             0.059649
# 560  {'Wait': 0.48373405977839634}         0.099415             0.054385
# 334   {'Wait': 0.5262687927936525}         0.096726             0.051562
# 607    {'Wait': 0.850489994816454}         0.082718             0.036854
# 449    {'Wait': 0.940505715270748}         0.081384             0.035453
# 266  {'Wait': 0.12882685152837114}         0.125846             0.082138
# 438   {'Wait': 0.7593596229783273}         0.080883             0.034927
# 563   {'Wait': 0.9987310488803898}         0.075255             0.029018
#
#      fc_p_value_fdr
# 567        0.997413
# 450        0.997413
# 273        0.997413
# 486        0.997413
# 4          0.997413
# 452        0.997413
# 569        0.997413
# 603        0.997413
# 562        0.997413
# 271        0.997413
# 570        0.997413
# 436        0.997413
# 677        0.997413
# 560        0.997413
# 334        0.997413
# 607        0.997413
# 449        0.997413
# 266        0.997413
# 438        0.997413
# 563        0.997413

# %%
df_deltaFC_vs_deltaYBOCS.loc[
    (df_deltaFC_vs_deltaYBOCS['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_deltaFC_vs_deltaYBOCS['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_deltaFC_vs_deltaYBOCS['fc_p_value'] <= 0.05)
]
# Out:
#                          ROI          network1          network2  fc_effect  \
# 273           ROI_40_Default  Dorsal Attention           Default  -0.009906
# 603  ROI_87_Dorsal Attention           Default  Dorsal Attention  -0.006635
#
#      fc_p_value   r_value   n               condition_effects  \
# 273    0.022464 -0.343851  43  {'Wait': 0.050623609883329986}
# 603    0.039749 -0.313745  43  {'Wait': 0.028332498747318954}
#
#                 condition_p_values  model_r_squared  model_adj_r_squared  \
# 273   {'Wait': 0.2982698778892731}         0.142055             0.099158
# 603  {'Wait': 0.43511709466541615}         0.112231             0.067843
#
#      fc_p_value_fdr
# 273        0.997413
# 603        0.997413

# %%
condition_baseline_FC_file = os.path.join(data_dir, 'condition_baseline_FC_schaefer_2018_100_7_2_roi_network_fc.csv')
condition_baseline_FC = pd.read_csv(condition_baseline_FC_file)
condition_baseline_FC.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                           ROI          network1           network2  \
# 83              ROI_12_Visual            Visual             Visual
# 581            ROI_84_Default    Frontoparietal            Default
# 82   ROI_12_Ventral Attention            Visual  Ventral Attention
# 639     ROI_92_Frontoparietal           Default     Frontoparietal
# 3                ROI_1_Limbic            Visual             Limbic
# 634        ROI_91_Somatomotor           Default        Somatomotor
# 574            ROI_83_Default    Frontoparietal            Default
# 18          ROI_3_Somatomotor            Visual        Somatomotor
# 78    ROI_12_Dorsal Attention            Visual   Dorsal Attention
# 646     ROI_93_Frontoparietal           Default     Frontoparietal
# 473        ROI_68_Somatomotor            Limbic        Somatomotor
# 77             ROI_12_Default            Visual            Default
# 266            ROI_39_Default  Dorsal Attention            Default
# 595            ROI_86_Default           Default            Default
# 425  ROI_61_Ventral Attention            Limbic  Ventral Attention
# 648        ROI_93_Somatomotor           Default        Somatomotor
# 644            ROI_93_Default           Default            Default
# 660     ROI_95_Frontoparietal           Default     Frontoparietal
# 603   ROI_87_Dorsal Attention           Default   Dorsal Attention
# 133            ROI_20_Default       Somatomotor            Default
#
#     reference_condition comparison_condition  t_statistic   p_value  \
# 83                Treat                 Wait    -2.702394  0.009756
# 581               Treat                 Wait    -2.574958  0.013609
# 82                Treat                 Wait    -2.547008  0.014481
# 639               Treat                 Wait    -2.422337  0.019645
# 3                 Treat                 Wait    -2.393738  0.021398
# 634               Treat                 Wait    -2.339063  0.025089
# 574               Treat                 Wait    -2.285871  0.027552
# 18                Treat                 Wait    -2.263739  0.028582
# 78                Treat                 Wait    -2.189700  0.033903
# 646               Treat                 Wait    -2.177594  0.034925
# 473               Treat                 Wait    -2.098557  0.041724
# 77                Treat                 Wait    -2.041965  0.047231
# 266               Treat                 Wait    -2.033385  0.048611
# 595               Treat                 Wait    -2.021410  0.049740
# 425               Treat                 Wait    -2.024854  0.049891
# 648               Treat                 Wait    -1.981179  0.053990
# 644               Treat                 Wait    -1.970800  0.055216
# 660               Treat                 Wait    -1.968872  0.055427
# 603               Treat                 Wait    -1.933532  0.059832
# 133               Treat                 Wait    -1.930351  0.060283
#
#      reference_mean  comparison_mean  reference_n  comparison_n  effect_size  \
# 83         0.494680         0.392146           24            22    -0.815129
# 581        0.447264         0.334120           24            22    -0.779100
# 82         0.293924         0.164729           24            22    -0.769023
# 639        0.401323         0.304216           24            22    -0.728073
# 3          0.281531         0.185280           24            22    -0.716233
# 634        0.235709         0.131996           24            22    -0.696821
# 574        0.546470         0.474354           24            22    -0.693053
# 18         0.335828         0.250264           24            22    -0.682498
# 78         0.269481         0.166526           24            22    -0.658874
# 646        0.398282         0.304826           24            22    -0.654064
# 473        0.459529         0.382522           24            22    -0.633914
# 77         0.286280         0.167423           24            22    -0.616355
# 266        0.389607         0.301831           24            22    -0.616611
# 595        0.536310         0.468109           24            22    -0.612364
# 425        0.281322         0.182730           24            22    -0.615277
# 648        0.312027         0.220330           24            22    -0.594674
# 644        0.508058         0.440857           24            22    -0.595739
# 660        0.465682         0.390617           24            22    -0.591036
# 603        0.367738         0.299318           24            22    -0.584777
# 133        0.421124         0.341836           24            22    -0.578813
#
#      p_value_fdr
# 83      0.765264
# 581     0.765264
# 82      0.765264
# 639     0.765264
# 3       0.765264
# 634     0.765264
# 574     0.765264
# 18      0.765264
# 78      0.765264
# 646     0.765264
# 473     0.765264
# 77      0.765264
# 266     0.765264
# 595     0.765264
# 425     0.765264
# 648     0.765264
# 644     0.765264
# 660     0.765264
# 603     0.765264
# 133     0.765264

# %%
condition_followup_FC_file = os.path.join(data_dir, 'condition_followup_FC_schaefer_2018_100_7_2_roi_network_fc.csv')
condition_followup_FC = pd.read_csv(condition_followup_FC_file)
condition_followup_FC.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                            ROI           network1           network2  \
# 694   ROI_100_Dorsal Attention   Dorsal Attention   Dorsal Attention
# 693            ROI_100_Default   Dorsal Attention            Default
# 377              ROI_54_Visual  Ventral Attention             Visual
# 698  ROI_100_Ventral Attention   Dorsal Attention  Ventral Attention
# 348   ROI_50_Ventral Attention  Ventral Attention  Ventral Attention
# 374              ROI_54_Limbic  Ventral Attention             Limbic
# 4            ROI_1_Somatomotor             Visual        Somatomotor
# 111              ROI_16_Visual        Somatomotor             Visual
# 368         ROI_53_Somatomotor  Ventral Attention        Somatomotor
# 25           ROI_4_Somatomotor             Visual        Somatomotor
# 108              ROI_16_Limbic        Somatomotor             Limbic
# 122              ROI_18_Limbic        Somatomotor             Limbic
# 361         ROI_52_Somatomotor  Ventral Attention        Somatomotor
# 690         ROI_99_Somatomotor        Somatomotor        Somatomotor
# 375         ROI_54_Somatomotor  Ventral Attention        Somatomotor
# 412              ROI_59_Visual             Limbic             Visual
# 360              ROI_52_Limbic  Ventral Attention             Limbic
# 403         ROI_58_Somatomotor             Limbic        Somatomotor
# 109         ROI_16_Somatomotor        Somatomotor        Somatomotor
# 344    ROI_50_Dorsal Attention  Ventral Attention   Dorsal Attention
#
#     reference_condition comparison_condition  t_statistic   p_value  \
# 694               Treat                 Wait    -2.784836  0.008364
# 693               Treat                 Wait    -2.718521  0.010203
# 377               Treat                 Wait    -2.548541  0.014688
# 698               Treat                 Wait    -2.443534  0.019028
# 348               Treat                 Wait    -2.432902  0.019658
# 374               Treat                 Wait    -2.355771  0.023368
# 4                 Treat                 Wait    -2.263419  0.028974
# 111               Treat                 Wait    -2.250847  0.029922
# 368               Treat                 Wait    -2.224196  0.031750
# 25                Treat                 Wait    -2.212926  0.033161
# 108               Treat                 Wait    -2.096089  0.042602
# 122               Treat                 Wait    -2.074392  0.044408
# 361               Treat                 Wait    -2.063379  0.045447
# 690               Treat                 Wait    -2.033318  0.048685
# 375               Treat                 Wait    -2.027124  0.049505
# 412               Treat                 Wait    -2.015646  0.050546
# 360               Treat                 Wait    -2.009250  0.051192
# 403               Treat                 Wait    -2.005400  0.051726
# 109               Treat                 Wait    -1.997313  0.052647
# 344               Treat                 Wait    -2.008522  0.052728
#
#      reference_mean  comparison_mean  reference_n  comparison_n  effect_size  \
# 694        0.312700         0.227492           21            22    -0.872924
# 693        0.436593         0.367194           21            22    -0.853447
# 377        0.554355         0.475676           21            22    -0.796618
# 698        0.388350         0.312793           21            22    -0.764319
# 348        0.428311         0.347191           21            22    -0.761754
# 374        0.444605         0.352775           21            22    -0.735029
# 4          0.297971         0.198435           21            22    -0.706493
# 111        0.481933         0.370658           21            22    -0.701689
# 368        0.453716         0.363842           21            22    -0.693740
# 25         0.377184         0.282839           21            22    -0.688224
# 108        0.454633         0.352384           21            22    -0.652746
# 122        0.471051         0.376824           21            22    -0.647061
# 361        0.345222         0.263257           21            22    -0.644261
# 690        0.147620         0.044093           21            22    -0.633721
# 375        0.370300         0.281824           21            22    -0.631288
# 412        0.530565         0.454591           21            22    -0.628355
# 360        0.443244         0.370374           21            22    -0.628164
# 403        0.390814         0.299469           21            22    -0.624965
# 109        0.463562         0.383557           21            22    -0.622398
# 344        0.419127         0.354440           21            22    -0.630846
#
#      p_value_fdr
# 694     0.975305
# 693     0.975305
# 377     0.975305
# 698     0.975305
# 348     0.975305
# 374     0.975305
# 4       0.975305
# 111     0.975305
# 368     0.975305
# 25      0.975305
# 108     0.975305
# 122     0.975305
# 361     0.975305
# 690     0.975305
# 375     0.975305
# 412     0.975305
# 360     0.975305
# 403     0.975305
# 109     0.975305
# 344     0.975305

# %%
condition_FC_change_file = os.path.join(data_dir, 'condition_FC_change_schaefer_2018_100_7_2_roi_network_fc.csv')
condition_FC_change = pd.read_csv(condition_FC_change_file)
condition_FC_change.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                            ROI           network1           network2  \
# 693            ROI_100_Default   Dorsal Attention            Default
# 660      ROI_95_Frontoparietal            Default     Frontoparietal
# 298         ROI_43_Somatomotor  Ventral Attention        Somatomotor
# 590      ROI_85_Frontoparietal            Default     Frontoparietal
# 662         ROI_95_Somatomotor            Default        Somatomotor
# 165         ROI_24_Somatomotor        Somatomotor        Somatomotor
# 574             ROI_83_Default     Frontoparietal            Default
# 698  ROI_100_Ventral Attention   Dorsal Attention  Ventral Attention
# 186         ROI_27_Somatomotor        Somatomotor        Somatomotor
# 348   ROI_50_Ventral Attention  Ventral Attention  Ventral Attention
# 694   ROI_100_Dorsal Attention   Dorsal Attention   Dorsal Attention
# 377              ROI_54_Visual  Ventral Attention             Visual
# 658             ROI_95_Default            Default            Default
# 319         ROI_46_Somatomotor  Ventral Attention        Somatomotor
# 675              ROI_97_Limbic            Default             Limbic
# 365    ROI_53_Dorsal Attention  Ventral Attention   Dorsal Attention
# 540    ROI_78_Dorsal Attention     Frontoparietal   Dorsal Attention
# 162    ROI_24_Dorsal Attention        Somatomotor   Dorsal Attention
# 294             ROI_43_Default  Ventral Attention            Default
# 678              ROI_97_Visual            Default             Visual
#
#     reference_condition comparison_condition  t_statistic   p_value  \
# 693               Treat                 Wait    -2.340652  0.024296
# 660               Treat                 Wait     2.297884  0.026747
# 298               Treat                 Wait     2.227882  0.032053
# 590               Treat                 Wait     2.170795  0.036154
# 662               Treat                 Wait     2.135084  0.039028
# 165               Treat                 Wait     2.103070  0.041641
# 574               Treat                 Wait     2.098884  0.043413
# 698               Treat                 Wait    -2.027836  0.049129
# 186               Treat                 Wait     2.000860  0.052061
# 348               Treat                 Wait    -1.993702  0.052875
# 694               Treat                 Wait    -1.852237  0.072392
# 377               Treat                 Wait    -1.753612  0.087059
# 658               Treat                 Wait     1.746031  0.088302
# 319               Treat                 Wait     1.741549  0.089091
# 675               Treat                 Wait     1.719273  0.093110
# 365               Treat                 Wait    -1.717470  0.093682
# 540               Treat                 Wait     1.716058  0.093794
# 162               Treat                 Wait     1.696558  0.097626
# 294               Treat                 Wait     1.688737  0.098870
# 678               Treat                 Wait     1.663594  0.103827
#
#      reference_mean  comparison_mean  reference_n  comparison_n  effect_size  \
# 693        0.020205        -0.056391           21            22    -0.729633
# 660       -0.072997         0.021791           21            22     0.717739
# 298       -0.079299         0.020524           21            22     0.692893
# 590       -0.049907         0.025420           21            22     0.675809
# 662       -0.092493         0.004172           21            22     0.668338
# 165       -0.044609         0.039808           21            22     0.656675
# 574       -0.062272         0.012047           21            22     0.651679
# 698        0.029465        -0.051861           21            22    -0.632776
# 186       -0.029837         0.048002           21            22     0.624930
# 348        0.031613        -0.053193           21            22    -0.622267
# 694        0.015890        -0.051549           21            22    -0.581251
# 377        0.035170        -0.024680           21            22    -0.548301
# 658       -0.048016         0.024868           21            22     0.545407
# 319       -0.081059         0.012489           21            22     0.543971
# 675       -0.090148         0.011443           21            22     0.536968
# 365        0.028603        -0.048749           21            22    -0.535120
# 540       -0.052348         0.012534           21            22     0.536578
# 162       -0.043651         0.038136           21            22     0.530970
# 294       -0.034535         0.039797           21            22     0.527115
# 678       -0.082434         0.004207           21            22     0.519651
#
#      p_value_fdr
# 693     0.995332
# 660     0.995332
# 298     0.995332
# 590     0.995332
# 662     0.995332
# 165     0.995332
# 574     0.995332
# 698     0.995332
# 186     0.995332
# 348     0.995332
# 694     0.995332
# 377     0.995332
# 658     0.995332
# 319     0.995332
# 675     0.995332
# 365     0.995332
# 540     0.995332
# 162     0.995332
# 294     0.995332
# 678     0.995332

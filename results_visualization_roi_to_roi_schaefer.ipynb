# %%
import pandas as pd
import numpy as np
import os
import glob
import os
import subprocess
import pandas as pd
import numpy as np
from scipy.stats import iqr
from statsmodels.formula.api import ols
from scipy.stats import zscore
from nipype.interfaces.fsl import ImageMaths
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import pandas as pd
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests
# Create bar plot
plt.style.use('seaborn-v0_8-poster')
#plt.style.use('seaborn-v0_8')
fontsize = 11
plt.rcParams.update({
    "font.size": fontsize,          # Global font size
    "axes.labelsize": fontsize,     # X and Y axis labels
    "axes.titlesize": fontsize,     # Title (if used)
    "xtick.labelsize": fontsize,    # X-axis tick labels
    "ytick.labelsize": fontsize,    # Y-axis tick labels
    "legend.fontsize": fontsize,    # Legend font size
})

# %%
project_dir = '/Users/xiaoqianxiao/projects/OCD'
data_dir = os.path.join(project_dir, 'results/NW_group_roi_roi')
result_dir = os.path.join(project_dir, 'results/visualization/NW_group_roi_roi')
if not os.path.exists(result_dir):
    os.makedirs(result_dir, exist_ok=True)

# %%
group_diff_file = os.path.join(data_dir, 'group_diff_baseline_schaefer_2018_100_7_2_roiroi_fc.csv')
df_group_diff = pd.read_csv(group_diff_file)
df_group_diff.sort_values(by='p_value', ascending=True)
# Out:
#                                    ROI1                               ROI2  \
# 1725    b'7Networks_LH_DorsAttn_Post_5'        b'7Networks_LH_Cont_pCun_1'
# 2986        b'7Networks_LH_Cont_Cing_1'      b'7Networks_RH_Default_Par_1'
# 2963        b'7Networks_LH_Cont_Cing_1'    b'7Networks_RH_DorsAttn_Post_1'
# 2925        b'7Networks_LH_Cont_pCun_1'     b'7Networks_RH_Default_Temp_2'
# 2883        b'7Networks_LH_Cont_pCun_1'  b'7Networks_LH_Default_pCunPCC_2'
# ...                                 ...                                ...
# 4324           b'7Networks_RH_SomMot_7'    b'7Networks_RH_DorsAttn_Post_4'
# 3337      b'7Networks_LH_Default_PFC_2'        b'7Networks_RH_Cont_PFCl_2'
# 1164           b'7Networks_LH_SomMot_4'              b'7Networks_RH_Vis_6'
# 1575    b'7Networks_LH_DorsAttn_Post_3'      b'7Networks_LH_Default_PFC_6'
# 2706  b'7Networks_LH_Limbic_TempPole_2'    b'7Networks_RH_DorsAttn_Post_2'
#
#                network1           network2  t_statistic   p_value  OCD_mean  \
# 1725        Somatomotor   Dorsal Attention     3.573719  0.000866  0.633078
# 2986   Dorsal Attention            Default     3.410961  0.001574  0.399486
# 2963   Dorsal Attention             Limbic     3.299098  0.001757  0.327977
# 2925   Dorsal Attention            Default     3.058898  0.003238  0.304779
# 2883   Dorsal Attention  Ventral Attention     3.111230  0.003419  0.587636
# ...                 ...                ...          ...       ...       ...
# 4324             Limbic             Limbic    -0.001451  0.998849  0.520946
# 3337  Ventral Attention     Frontoparietal    -0.000427  0.999661  0.369081
# 1164             Visual  Ventral Attention     0.000316  0.999749  0.355318
# 1575        Somatomotor  Ventral Attention    -0.000269  0.999786  0.358525
# 2706   Dorsal Attention             Limbic     0.000263  0.999791  0.073201
#
#        HC_mean   OCD_std    HC_std  OCD_n  HC_n  cohens_d  p_corrected  \
# 1725  0.505706  0.129853  0.146609     46    25  0.919754     0.952829
# 2986  0.227364  0.155686  0.219512     46    25  0.904505     0.952829
# 2963  0.174736  0.191750  0.179363     46    25  0.825383     0.952829
# 2925  0.179597  0.198461  0.138522     46    25  0.731479     0.952829
# 2883  0.438527  0.160645  0.203378     46    25  0.813645     0.952829
# ...        ...       ...       ...    ...   ...       ...          ...
# 4324  0.521015  0.173289  0.197321     46    25 -0.000374     0.999657
# 3337  0.369102  0.200760  0.198783     46    25 -0.000108     0.999791
# 1164  0.355301  0.215031  0.207080     46    25  0.000080     0.999791
# 1575  0.358541  0.240447  0.230081     46    25 -0.000068     0.999791
# 2706  0.073189  0.183786  0.167257     46    25  0.000066     0.999791
#
#       significant
# 1725        False
# 2986        False
# 2963        False
# 2925        False
# 2883        False
# ...           ...
# 4324        False
# 3337        False
# 1164        False
# 1575        False
# 2706        False
#
# [4950 rows x 15 columns]

# %%
df_group_diff.loc[
    (df_group_diff['p_value'] <= 0.05)
]
# Out:
#                                    ROI1                                ROI2  \
# 47                b'7Networks_LH_Vis_1'   b'7Networks_LH_Default_pCunPCC_1'
# 48                b'7Networks_LH_Vis_1'   b'7Networks_LH_Default_pCunPCC_2'
# 77                b'7Networks_LH_Vis_1'        b'7Networks_RH_Limbic_OFC_1'
# 97                b'7Networks_LH_Vis_1'   b'7Networks_RH_Default_pCunPCC_1'
# 98                b'7Networks_LH_Vis_1'   b'7Networks_RH_Default_pCunPCC_2'
# ...                                 ...                                 ...
# 4738       b'7Networks_RH_Limbic_OFC_1'   b'7Networks_RH_Default_pCunPCC_1'
# 4757  b'7Networks_RH_Limbic_TempPole_1'  b'7Networks_RH_Default_PFCdPFCm_3'
# 4771         b'7Networks_RH_Cont_Par_1'      b'7Networks_RH_Default_Temp_3'
# 4861        b'7Networks_RH_Cont_Cing_1'       b'7Networks_RH_Default_Par_1'
# 4864        b'7Networks_RH_Cont_Cing_1'      b'7Networks_RH_Default_Temp_3'
#
#             network1           network2  t_statistic   p_value  OCD_mean  \
# 47            Visual  Ventral Attention     2.569243  0.013188  0.592309
# 48            Visual  Ventral Attention     2.334045  0.023900  0.396353
# 77            Visual     Frontoparietal    -2.796230  0.007277  0.224057
# 97            Visual        Somatomotor     2.834481  0.006417  0.592452
# 98            Visual   Dorsal Attention     2.746030  0.008218  0.388040
# ...              ...                ...          ...       ...       ...
# 4738  Frontoparietal        Somatomotor    -2.095679  0.041816  0.121958
# 4757  Frontoparietal            Default     2.053876  0.046592  0.381500
# 4771  Frontoparietal            Default     2.110004  0.039753  0.261861
# 4861         Default            Default     2.520723  0.015656  0.436941
# 4864         Default            Default     2.207080  0.032502  0.357215
#
#        HC_mean   OCD_std    HC_std  OCD_n  HC_n  cohens_d  p_corrected  \
# 47    0.499338  0.146538  0.141330     46    25  0.645824     0.952829
# 48    0.297996  0.162041  0.169160     46    25  0.593804     0.952829
# 77    0.344269  0.174985  0.167413     46    25 -0.702011     0.952829
# 97    0.495138  0.147306  0.129292     46    25  0.702167     0.952829
# 98    0.278597  0.167211  0.152350     46    25  0.684220     0.952829
# ...        ...       ...       ...    ...   ...       ...          ...
# 4738  0.226869  0.183980  0.205163     46    25 -0.538388     0.952829
# 4757  0.275772  0.170781  0.219186     46    25  0.538111     0.952829
# 4771  0.127001  0.261748  0.247995     46    25  0.528936     0.952829
# 4861  0.309858  0.173537  0.211991     46    25  0.656016     0.952829
# 4864  0.238923  0.196773  0.219755     46    25  0.567130     0.952829
#
#       significant
# 47          False
# 48          False
# 77          False
# 97          False
# 98          False
# ...           ...
# 4738        False
# 4757        False
# 4771        False
# 4861        False
# 4864        False
#
# [178 rows x 15 columns]

# %%
df_group_diff.loc[
    (df_group_diff['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_group_diff['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_group_diff['p_value'] <= 0.05)]
# Out:
#                                    ROI1                                ROI2  \
# 2733  b'7Networks_LH_Limbic_TempPole_2'      b'7Networks_RH_Default_PFCv_2'
# 2735  b'7Networks_LH_Limbic_TempPole_2'  b'7Networks_RH_Default_PFCdPFCm_2'
# 2789         b'7Networks_LH_Cont_Par_1'         b'7Networks_RH_Cont_PFCl_3'
# 2792         b'7Networks_LH_Cont_Par_1'        b'7Networks_RH_Cont_PFCmp_1'
# 2871        b'7Networks_LH_Cont_pCun_1'      b'7Networks_LH_Default_Temp_1'
# 2874        b'7Networks_LH_Cont_pCun_1'       b'7Networks_LH_Default_Par_2'
# 2922        b'7Networks_LH_Cont_pCun_1'         b'7Networks_RH_Cont_pCun_1'
# 2923        b'7Networks_LH_Cont_pCun_1'       b'7Networks_RH_Default_Par_1'
# 2925        b'7Networks_LH_Cont_pCun_1'      b'7Networks_RH_Default_Temp_2'
# 2926        b'7Networks_LH_Cont_pCun_1'      b'7Networks_RH_Default_Temp_3'
# 2929        b'7Networks_LH_Cont_pCun_1'  b'7Networks_RH_Default_PFCdPFCm_1'
# 2930        b'7Networks_LH_Cont_pCun_1'  b'7Networks_RH_Default_PFCdPFCm_2'
# 2931        b'7Networks_LH_Cont_pCun_1'  b'7Networks_RH_Default_PFCdPFCm_3'
# 2933        b'7Networks_LH_Cont_pCun_1'   b'7Networks_RH_Default_pCunPCC_2'
# 2934        b'7Networks_LH_Cont_Cing_1'      b'7Networks_LH_Default_Temp_1'
# 2937        b'7Networks_LH_Cont_Cing_1'       b'7Networks_LH_Default_Par_2'
# 2985        b'7Networks_LH_Cont_Cing_1'         b'7Networks_RH_Cont_pCun_1'
# 2986        b'7Networks_LH_Cont_Cing_1'       b'7Networks_RH_Default_Par_1'
# 2988        b'7Networks_LH_Cont_Cing_1'      b'7Networks_RH_Default_Temp_2'
# 2989        b'7Networks_LH_Cont_Cing_1'      b'7Networks_RH_Default_Temp_3'
# 2994        b'7Networks_LH_Cont_Cing_1'  b'7Networks_RH_Default_PFCdPFCm_3'
# 3045     b'7Networks_LH_Default_Temp_1'         b'7Networks_RH_Cont_Cing_1'
# 3106     b'7Networks_LH_Default_Temp_2'         b'7Networks_RH_Cont_Cing_1'
# 3225      b'7Networks_LH_Default_Par_2'         b'7Networks_RH_Cont_Cing_1'
# 4861        b'7Networks_RH_Cont_Cing_1'       b'7Networks_RH_Default_Par_1'
# 4864        b'7Networks_RH_Cont_Cing_1'      b'7Networks_RH_Default_Temp_3'
#
#               network1          network2  t_statistic   p_value  OCD_mean  \
# 2733  Dorsal Attention           Default     2.228928  0.030161  0.261180
# 2735  Dorsal Attention           Default     2.087554  0.042253  0.357161
# 2789  Dorsal Attention           Default     2.948080  0.004972  0.366327
# 2792  Dorsal Attention           Default     2.112282  0.039960  0.363576
# 2871  Dorsal Attention  Dorsal Attention     2.476649  0.016547  0.267102
# 2874  Dorsal Attention  Dorsal Attention     2.562660  0.013447  0.413634
# 2922  Dorsal Attention           Default     2.237701  0.031078  0.795478
# 2923  Dorsal Attention           Default     2.406365  0.020428  0.350527
# 2925  Dorsal Attention           Default     3.058898  0.003238  0.304779
# 2926  Dorsal Attention           Default     2.442399  0.018370  0.296148
# 2929  Dorsal Attention           Default     2.460778  0.017793  0.389288
# 2930  Dorsal Attention           Default     2.649099  0.011088  0.279545
# 2931  Dorsal Attention           Default     2.638405  0.011334  0.386098
# 2933  Dorsal Attention  Dorsal Attention     2.506665  0.015934  0.538651
# 2934  Dorsal Attention  Dorsal Attention     2.040896  0.046326  0.331090
# 2937  Dorsal Attention  Dorsal Attention     2.212520  0.031852  0.458073
# 2985  Dorsal Attention           Default     2.471163  0.016705  0.596527
# 2986  Dorsal Attention           Default     3.410961  0.001574  0.399486
# 2988  Dorsal Attention           Default     2.628544  0.011413  0.332367
# 2989  Dorsal Attention           Default     2.800793  0.007474  0.346162
# 2994  Dorsal Attention           Default     2.420459  0.019812  0.392015
# 3045  Dorsal Attention           Default     2.180741  0.033952  0.292284
# 3106  Dorsal Attention           Default     2.044905  0.046080  0.239323
# 3225  Dorsal Attention           Default     2.338746  0.024040  0.400895
# 4861           Default           Default     2.520723  0.015656  0.436941
# 4864           Default           Default     2.207080  0.032502  0.357215
#
#        HC_mean   OCD_std    HC_std  OCD_n  HC_n  cohens_d  p_corrected  \
# 2733  0.162765  0.182681  0.170265     46    25  0.557333     0.952829
# 2735  0.256684  0.185294  0.193101     46    25  0.530957     0.952829
# 2789  0.222136  0.187059  0.196853     46    25  0.750924     0.952829
# 2792  0.266642  0.176986  0.183947     46    25  0.537029     0.952829
# 2871  0.144618  0.204717  0.190652     46    25  0.619198     0.952829
# 2874  0.295497  0.185104  0.180913     46    25  0.645484     0.952829
# 2922  0.748140  0.068089  0.090929     46    25  0.589334     0.952829
# 2923  0.238782  0.167093  0.191998     46    25  0.620885     0.952829
# 2925  0.179597  0.198461  0.138522     46    25  0.731479     0.952829
# 2926  0.176531  0.188980  0.196262     46    25  0.620887     0.952829
# 2929  0.262656  0.189395  0.210771     46    25  0.631995     0.952829
# 2930  0.132476  0.205737  0.226708     46    25  0.679381     0.952829
# 2931  0.254773  0.187286  0.201873     46    25  0.674444     0.952829
# 2933  0.423246  0.168025  0.189245     46    25  0.644903     0.952829
# 2934  0.231091  0.203333  0.188594     46    25  0.509932     0.952829
# 2937  0.357150  0.174078  0.183780     46    25  0.563834     0.952829
# 2985  0.518324  0.132966  0.120855     46    25  0.615501     0.952829
# 2986  0.227364  0.155686  0.219512     46    25  0.904505     0.952829
# 2988  0.218741  0.171376  0.170832     46    25  0.664076     0.952829
# 2989  0.211673  0.178442  0.195847     46    25  0.717863     0.952829
# 2994  0.269021  0.180468  0.211189     46    25  0.626149     0.952829
# 3045  0.176306  0.213068  0.208972     46    25  0.549579     0.952829
# 3106  0.122111  0.232376  0.223722     46    25  0.513883     0.952829
# 3225  0.290624  0.168676  0.195396     46    25  0.604138     0.952829
# 4861  0.309858  0.173537  0.211991     46    25  0.656016     0.952829
# 4864  0.238923  0.196773  0.219755     46    25  0.567130     0.952829
#
#       significant
# 2733        False
# 2735        False
# 2789        False
# 2792        False
# 2871        False
# 2874        False
# 2922        False
# 2923        False
# 2925        False
# 2926        False
# 2929        False
# 2930        False
# 2931        False
# 2933        False
# 2934        False
# 2937        False
# 2985        False
# 2986        False
# 2988        False
# 2989        False
# 2994        False
# 3045        False
# 3106        False
# 3225        False
# 4861        False
# 4864        False

# %%
baselineFC_vs_deltaYBOCS_file = os.path.join(data_dir, 'baselineFC_vs_deltaYBOCS_schaefer_2018_100_7_2_roiroi_fc.csv')
df_baselineFC_vs_deltaYBOCS = pd.read_csv(baselineFC_vs_deltaYBOCS_file)
df_baselineFC_vs_deltaYBOCS.sort_values(by='fc_p_value', ascending=True).head(20)
# Out:
#                                           ROI1  \
# 2075     b'7Networks_LH_SalVentAttn_ParOper_1'
# 4605  b'7Networks_RH_SalVentAttn_TempOccPar_1'
# 2191   b'7Networks_LH_SalVentAttn_FrOperIns_2'
# 2515         b'7Networks_LH_SalVentAttn_Med_3'
# 2025     b'7Networks_LH_SalVentAttn_ParOper_1'
# 2155   b'7Networks_LH_SalVentAttn_FrOperIns_1'
# 3314             b'7Networks_LH_Default_PFC_2'
# 1489           b'7Networks_LH_DorsAttn_Post_2'
# 3981                     b'7Networks_RH_Vis_6'
# 3328             b'7Networks_LH_Default_PFC_2'
# 341                      b'7Networks_LH_Vis_4'
# 1872           b'7Networks_LH_DorsAttn_PrCv_1'
# 16                       b'7Networks_LH_Vis_1'
# 2483         b'7Networks_LH_SalVentAttn_Med_3'
# 4335                  b'7Networks_RH_SomMot_7'
# 3652         b'7Networks_LH_Default_pCunPCC_1'
# 2578              b'7Networks_LH_Limbic_OFC_1'
# 343                      b'7Networks_LH_Vis_4'
# 2652         b'7Networks_LH_Limbic_TempPole_1'
# 2178   b'7Networks_LH_SalVentAttn_FrOperIns_2'
#
#                                           ROI2           network1  \
# 2075   b'7Networks_RH_SalVentAttn_FrOperIns_1'        Somatomotor
# 4605                b'7Networks_RH_Cont_Par_1'     Frontoparietal
# 2191             b'7Networks_LH_Default_PFC_2'        Somatomotor
# 2515                b'7Networks_RH_Cont_Par_1'   Dorsal Attention
# 2025   b'7Networks_LH_SalVentAttn_FrOperIns_2'        Somatomotor
# 2155                b'7Networks_RH_Cont_Par_1'        Somatomotor
# 3314                  b'7Networks_RH_SomMot_3'  Ventral Attention
# 1489             b'7Networks_LH_Default_PFC_2'        Somatomotor
# 3981         b'7Networks_RH_SalVentAttn_Med_2'  Ventral Attention
# 3328  b'7Networks_RH_SalVentAttn_TempOccPar_2'  Ventral Attention
# 341                      b'7Networks_RH_Vis_2'             Visual
# 1872   b'7Networks_LH_SalVentAttn_FrOperIns_2'        Somatomotor
# 16             b'7Networks_LH_DorsAttn_Post_3'             Visual
# 2483         b'7Networks_LH_Default_pCunPCC_1'   Dorsal Attention
# 4335                b'7Networks_RH_Cont_Par_1'             Limbic
# 3652         b'7Networks_RH_SalVentAttn_Med_2'  Ventral Attention
# 2578  b'7Networks_RH_SalVentAttn_TempOccPar_2'   Dorsal Attention
# 343                      b'7Networks_RH_Vis_4'             Visual
# 2652                b'7Networks_RH_Cont_Par_1'   Dorsal Attention
# 2178         b'7Networks_LH_SalVentAttn_Med_3'        Somatomotor
#
#                network2  fc_effect  fc_p_value   r_value   n  \
# 2075     Frontoparietal  -0.011172    0.001617 -0.464849  44
# 4605     Frontoparietal  -0.015583    0.002189 -0.455429  44
# 2191  Ventral Attention  -0.015749    0.002400 -0.451428  44
# 2515     Frontoparietal  -0.016734    0.003366 -0.435746  44
# 2025        Somatomotor  -0.012402    0.003456 -0.437319  44
# 2155     Frontoparietal  -0.013134    0.004571 -0.421124  44
# 3314             Limbic  -0.014174    0.005208 -0.419750  44
# 1489  Ventral Attention  -0.015509    0.007424 -0.402348  44
# 3981     Frontoparietal   0.011889    0.007707  0.368291  44
# 3328     Frontoparietal  -0.014907    0.008271 -0.393619  44
# 341   Ventral Attention   0.008166    0.009247  0.385133  44
# 1872        Somatomotor  -0.010971    0.010948 -0.385483  44
# 16          Somatomotor  -0.011695    0.011152 -0.375607  44
# 2483  Ventral Attention   0.013011    0.011244  0.365812  44
# 4335     Frontoparietal  -0.014740    0.012268 -0.375268  44
# 3652     Frontoparietal   0.013000    0.012594  0.373844  44
# 2578     Frontoparietal  -0.012982    0.013688 -0.371368  44
# 343   Ventral Attention   0.005423    0.013873  0.374062  44
# 2652     Frontoparietal  -0.011427    0.014114 -0.369853  44
# 2178   Dorsal Attention  -0.011495    0.014666 -0.371075  44
#
#                     condition_effects              condition_p_values  \
# 2075   {'Wait': 0.012855654362014093}    {'Wait': 0.7350894998174656}
# 4605  {'Wait': -0.040927118824981276}    {'Wait': 0.4558879248281976}
# 2191  {'Wait': -0.048564231395835475}    {'Wait': 0.3867352245129515}
# 2515   {'Wait': 0.019752325125828835}    {'Wait': 0.7489314110600864}
# 2025  {'Wait': -0.016022879887018365}    {'Wait': 0.7269559878031858}
# 2155   {'Wait': 0.026604288716589534}    {'Wait': 0.5969871742849326}
# 3314   {'Wait': -0.03773130501663852}    {'Wait': 0.4947776526128965}
# 1489   {'Wait': -0.07360375144585254}   {'Wait': 0.24791784821057222}
# 3981   {'Wait': -0.11870118304442988}  {'Wait': 0.018494025207935253}
# 3328    {'Wait': 0.03819018836568115}    {'Wait': 0.5364918836315479}
# 341    {'Wait': -0.03171604553690371}    {'Wait': 0.3576754552794301}
# 1872  {'Wait': -0.014209176357230013}    {'Wait': 0.7636664187612042}
# 16     {'Wait': -0.10765312373394997}     {'Wait': 0.037908140250412}
# 2483   {'Wait': -0.09155572248247211}   {'Wait': 0.10908700866428732}
# 4335    {'Wait': 0.03550406039596749}     {'Wait': 0.583024875204954}
# 3652   {'Wait': -0.03223058546410106}     {'Wait': 0.573608410227559}
# 2578   {'Wait': -0.08758579584970447}   {'Wait': 0.13519680596595432}
# 343    {'Wait': 0.014888941804070605}    {'Wait': 0.5394780180017298}
# 2652    {'Wait': 0.01797491500405963}    {'Wait': 0.7254529519766193}
# 2178   {'Wait': -0.04141050254310123}    {'Wait': 0.4255062011653614}
#
#       model_r_squared  model_adj_r_squared  fc_p_value_fdr
# 2075         0.218297             0.180165        0.999964
# 4605         0.218221             0.180085        0.999964
# 2191         0.218380             0.180252        0.999964
# 2515         0.191921             0.152503        0.999964
# 2025         0.193679             0.154346        0.999964
# 2155         0.183004             0.143151        0.999964
# 3314         0.185616             0.145890        0.999964
# 1489         0.189057             0.149499        0.999964
# 3981         0.246284             0.209518        0.999964
# 3328         0.162870             0.122035        0.999964
# 341          0.165933             0.125246        0.999964
# 1872         0.150495             0.109056        0.999964
# 16           0.227759             0.190089        0.999964
# 2483         0.187017             0.147359        0.999964
# 4335         0.147195             0.105595        0.999964
# 3652         0.146459             0.104823        0.999964
# 2578         0.184129             0.144331        0.999964
# 343          0.147880             0.106313        0.999964
# 2652         0.139415             0.097436        0.999964
# 2178         0.151112             0.109702        0.999964

# %%
df_baselineFC_vs_deltaYBOCS.loc[
    (df_baselineFC_vs_deltaYBOCS['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_baselineFC_vs_deltaYBOCS['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_baselineFC_vs_deltaYBOCS['fc_p_value'] <= 0.05)
]
# Out:
#                                    ROI1                            ROI2  \
# 2395  b'7Networks_LH_SalVentAttn_Med_2'    b'7Networks_LH_Limbic_OFC_1'
# 2398  b'7Networks_LH_SalVentAttn_Med_2'      b'7Networks_LH_Cont_Par_1'
# 2468  b'7Networks_LH_SalVentAttn_Med_3'      b'7Networks_LH_Cont_Par_1'
# 2519  b'7Networks_LH_SalVentAttn_Med_3'     b'7Networks_RH_Cont_PFCl_3'
# 2860        b'7Networks_LH_Cont_PFCl_1'  b'7Networks_RH_Default_Temp_1'
# 3288      b'7Networks_LH_Default_PFC_1'  b'7Networks_RH_Default_Temp_2'
# 4929     b'7Networks_RH_Default_PFCv_1'  b'7Networks_RH_Default_PFCv_2'
#
#               network1          network2  fc_effect  fc_p_value   r_value   n  \
# 2395  Dorsal Attention  Dorsal Attention  -0.013348    0.018113 -0.354088  44
# 2398  Dorsal Attention  Dorsal Attention  -0.014793    0.029760 -0.333385  44
# 2468  Dorsal Attention  Dorsal Attention  -0.013458    0.034689 -0.324535  44
# 2519  Dorsal Attention           Default  -0.012863    0.034099 -0.325610  44
# 2860  Dorsal Attention           Default   0.011701    0.049504  0.290540  44
# 3288  Dorsal Attention           Default  -0.008761    0.040578 -0.315445  44
# 4929           Default           Default  -0.006880    0.040447 -0.315364  44
#
#                     condition_effects             condition_p_values  \
# 2395   {'Wait': -0.11996692601036395}  {'Wait': 0.05928515977504203}
# 2398  {'Wait': -0.037475084402807696}   {'Wait': 0.6196613591009352}
# 2468  {'Wait': -0.032796377968296576}   {'Wait': 0.6431473100880398}
# 2519   {'Wait': -0.05433391144040316}   {'Wait': 0.4215592972260248}
# 2860   {'Wait': -0.08216957758818236}  {'Wait': 0.21973270874439055}
# 3288   {'Wait': -0.03151148185020781}   {'Wait': 0.5085815956515221}
# 4929   {'Wait': -0.03641403311494402}   {'Wait': 0.3318713250425961}
#
#       model_r_squared  model_adj_r_squared  fc_p_value_fdr
# 2395         0.198911             0.159833        0.999964
# 2398         0.116535             0.073440        0.999964
# 2468         0.110052             0.066639        0.999964
# 2519         0.120166             0.077247        0.999964
# 2860         0.117833             0.074801        0.999964
# 3288         0.109168             0.065713        0.999964
# 4929         0.120148             0.077228        0.999964

# %%
deltaFC_vs_deltaYBOCS_file = os.path.join(data_dir, 'deltaFC_vs_deltaYBOCS_schaefer_2018_100_7_2_roiroi_fc.csv')
df_deltaFC_vs_deltaYBOCS = pd.read_csv(deltaFC_vs_deltaYBOCS_file)
df_deltaFC_vs_deltaYBOCS.sort_values(by='fc_p_value', ascending=True).head(20)
# Out:
#                                  ROI1  \
# 18              b'7Networks_LH_Vis_1'
# 4324         b'7Networks_RH_SomMot_7'
# 4253         b'7Networks_RH_SomMot_5'
# 16              b'7Networks_LH_Vis_1'
# 3519    b'7Networks_LH_Default_PFC_6'
# 4016            b'7Networks_RH_Vis_7'
# 1691  b'7Networks_LH_DorsAttn_Post_4'
# 1593  b'7Networks_LH_DorsAttn_Post_3'
# 4766       b'7Networks_RH_Cont_Par_1'
# 2856      b'7Networks_LH_Cont_PFCl_1'
# 884          b'7Networks_LH_SomMot_1'
# 4329         b'7Networks_RH_SomMot_7'
# 3855            b'7Networks_RH_Vis_3'
# 1591  b'7Networks_LH_DorsAttn_Post_3'
# 1919  b'7Networks_LH_DorsAttn_PrCv_1'
# 4582   b'7Networks_RH_DorsAttn_FEF_1'
# 3467    b'7Networks_LH_Default_PFC_5'
# 1428  b'7Networks_LH_DorsAttn_Post_1'
# 4323         b'7Networks_RH_SomMot_7'
# 1726  b'7Networks_LH_DorsAttn_Post_5'
#
#                                           ROI2           network1  \
# 18             b'7Networks_LH_DorsAttn_Post_5'             Visual
# 4324           b'7Networks_RH_DorsAttn_Post_4'             Limbic
# 4253           b'7Networks_RH_DorsAttn_Post_4'             Limbic
# 16             b'7Networks_LH_DorsAttn_Post_3'             Visual
# 3519             b'7Networks_LH_Default_PFC_7'  Ventral Attention
# 4016           b'7Networks_RH_DorsAttn_Post_4'             Limbic
# 1691                b'7Networks_RH_Cont_Par_2'        Somatomotor
# 1593                  b'7Networks_RH_SomMot_7'        Somatomotor
# 4766              b'7Networks_RH_Cont_PFCmp_1'     Frontoparietal
# 2856               b'7Networks_RH_Cont_Cing_1'   Dorsal Attention
# 884              b'7Networks_LH_Default_Par_1'             Visual
# 4329  b'7Networks_RH_SalVentAttn_TempOccPar_2'             Limbic
# 3855               b'7Networks_RH_Cont_Cing_1'  Ventral Attention
# 1591                  b'7Networks_RH_SomMot_5'        Somatomotor
# 1919            b'7Networks_RH_DorsAttn_FEF_1'        Somatomotor
# 4582               b'7Networks_RH_Cont_PFCl_2'     Frontoparietal
# 3467         b'7Networks_LH_Default_pCunPCC_1'  Ventral Attention
# 1428                  b'7Networks_RH_SomMot_7'        Somatomotor
# 4323           b'7Networks_RH_DorsAttn_Post_3'             Limbic
# 1726               b'7Networks_LH_Cont_Cing_1'        Somatomotor
#
#                network2  fc_effect  fc_p_value   r_value   n  \
# 18          Somatomotor   0.017663    0.000226  0.504289  43
# 4324             Limbic   0.015234    0.000280  0.525387  43
# 4253             Limbic   0.021728    0.000456  0.516025  43
# 16          Somatomotor   0.018762    0.001230  0.482483  43
# 3519  Ventral Attention  -0.010392    0.002254 -0.457600  43
# 4016             Limbic   0.013970    0.004498  0.428915  43
# 1691     Frontoparietal   0.018461    0.005579  0.419561  43
# 1593             Limbic   0.014206    0.006543  0.401287  43
# 4766            Default   0.011381    0.006639  0.412825  43
# 2856            Default  -0.016773    0.007467 -0.403160  43
# 884    Dorsal Attention  -0.016027    0.008193 -0.400984  43
# 4329     Frontoparietal   0.010843    0.008943  0.390678  43
# 3855            Default  -0.014428    0.009181 -0.396173  43
# 1591             Limbic   0.018649    0.010264  0.386903  43
# 1919     Frontoparietal   0.012719    0.010318  0.391532  43
# 4582     Frontoparietal   0.011653    0.010778  0.390220  43
# 3467  Ventral Attention  -0.011044    0.011528 -0.386699  43
# 1428             Limbic   0.015672    0.011802  0.368097  43
# 4323             Limbic   0.011771    0.012069  0.383443  43
# 1726   Dorsal Attention  -0.013247    0.012134 -0.383362  43
#
#                      condition_effects              condition_p_values  \
# 18      {'Wait': -0.12939180251550017}  {'Wait': 0.013678535567382468}
# 4324    {'Wait': -0.04559472548994951}   {'Wait': 0.30677292039103315}
# 4253   {'Wait': -0.017845303175075537}    {'Wait': 0.7866875669299911}
# 16      {'Wait': 0.014703676306293899}    {'Wait': 0.8140313445797571}
# 3519     {'Wait': 0.01001785426228054}    {'Wait': 0.7860543433845015}
# 4016     {'Wait': 0.05060036563653752}   {'Wait': 0.34925871107460205}
# 1691   {'Wait': -0.016103056006814033}    {'Wait': 0.8254843965491732}
# 1593    {'Wait': -0.07784939397681094}    {'Wait': 0.1797307349154737}
# 4766    {'Wait': 0.029137527214804147}    {'Wait': 0.5279541599234254}
# 2856     {'Wait': 0.04600726711054636}     {'Wait': 0.505825135930343}
# 884     {'Wait': 0.025471768272408116}    {'Wait': 0.7029757647244796}
# 4329     {'Wait': 0.08433417681878835}   {'Wait': 0.07077282565666097}
# 3855    {'Wait': -0.06366113954660872}    {'Wait': 0.3003809521319062}
# 1591    {'Wait': -0.06326233298403222}     {'Wait': 0.432032229444674}
# 1919     {'Wait': 0.04581640870978172}    {'Wait': 0.4046700723315907}
# 4582    {'Wait': 0.014923726698241588}     {'Wait': 0.767623134333822}
# 3467  {'Wait': -0.0069120509984767105}    {'Wait': 0.8862693370663439}
# 1428    {'Wait': -0.11771922260727351}   {'Wait': 0.09290033474368872}
# 4323   {'Wait': -0.008030379705779246}    {'Wait': 0.8769646144325687}
# 1726   {'Wait': -0.052663270122726154}   {'Wait': 0.36971490984328836}
#
#       model_r_squared  model_adj_r_squared  fc_p_value_fdr
# 18           0.360653             0.328685        0.693211
# 4324         0.294922             0.259669        0.693211
# 4253         0.267641             0.231023        0.752658
# 16           0.233864             0.195557        0.998294
# 3519         0.210871             0.171414        0.998294
# 4016         0.201867             0.161961        0.998294
# 1691         0.177045             0.135897        0.998294
# 1593         0.198397             0.158317        0.998294
# 4766         0.178747             0.137684        0.998294
# 2856         0.171871             0.130464        0.998294
# 884          0.163872             0.122065        0.998294
# 4329         0.219844             0.180836        0.998294
# 3855         0.179533             0.138510        0.998294
# 1591         0.162879             0.121023        0.998294
# 1919         0.168051             0.126453        0.998294
# 4582         0.154143             0.111850        0.998294
# 3467         0.149977             0.107476        0.998294
# 1428         0.195123             0.154879        0.998294
# 4323         0.147546             0.104923        0.998294
# 1726         0.164165             0.122374        0.998294

# %%
df_deltaFC_vs_deltaYBOCS.loc[
    (df_deltaFC_vs_deltaYBOCS['network1'].isin(['Default', 'Dorsal Attention'])) &
    (df_deltaFC_vs_deltaYBOCS['network2'].isin(['Default', 'Dorsal Attention'])) &
    (df_deltaFC_vs_deltaYBOCS['fc_p_value'] <= 0.05)
]
# Out:
#                                     ROI1                                ROI2  \
# 2468   b'7Networks_LH_SalVentAttn_Med_3'          b'7Networks_LH_Cont_Par_1'
# 2541        b'7Networks_LH_Limbic_OFC_1'      b'7Networks_LH_Default_Temp_1'
# 2736   b'7Networks_LH_Limbic_TempPole_2'  b'7Networks_RH_Default_PFCdPFCm_3'
# 2791          b'7Networks_LH_Cont_Par_1'         b'7Networks_RH_Cont_Cing_1'
# 2805         b'7Networks_LH_Cont_PFCl_1'         b'7Networks_LH_Cont_pCun_1'
# 2856         b'7Networks_LH_Cont_PFCl_1'         b'7Networks_RH_Cont_Cing_1'
# 2869         b'7Networks_LH_Cont_PFCl_1'   b'7Networks_RH_Default_pCunPCC_2'
# 3106      b'7Networks_LH_Default_Temp_2'         b'7Networks_RH_Cont_Cing_1'
# 3119      b'7Networks_LH_Default_Temp_2'   b'7Networks_RH_Default_pCunPCC_2'
# 3168       b'7Networks_LH_Default_Par_1'         b'7Networks_RH_Cont_pCun_1'
# 3230       b'7Networks_LH_Default_Par_2'      b'7Networks_RH_Default_Temp_2'
# 3238       b'7Networks_LH_Default_Par_2'   b'7Networks_RH_Default_pCunPCC_2'
# 4943  b'7Networks_RH_Default_PFCdPFCm_1'   b'7Networks_RH_Default_pCunPCC_2'
#
#               network1          network2  fc_effect  fc_p_value   r_value   n  \
# 2468  Dorsal Attention  Dorsal Attention   0.010013    0.049119  0.305615  43
# 2541  Dorsal Attention  Dorsal Attention   0.010576    0.043202  0.314471  43
# 2736  Dorsal Attention           Default  -0.012644    0.017317 -0.366248  43
# 2791  Dorsal Attention           Default  -0.013108    0.013832 -0.375098  43
# 2805  Dorsal Attention  Dorsal Attention  -0.014788    0.021610 -0.346902  43
# 2856  Dorsal Attention           Default  -0.016773    0.007467 -0.403160  43
# 2869  Dorsal Attention  Dorsal Attention  -0.014934    0.044516 -0.307643  43
# 3106  Dorsal Attention           Default  -0.012992    0.038904 -0.295385  43
# 3119  Dorsal Attention  Dorsal Attention  -0.015303    0.016312 -0.368105  43
# 3168  Dorsal Attention           Default  -0.012899    0.043034 -0.308520  43
# 3230  Dorsal Attention           Default   0.009580    0.026782  0.342425  43
# 3238  Dorsal Attention  Dorsal Attention  -0.009738    0.037116 -0.323469  43
# 4943           Default  Dorsal Attention   0.009926    0.046034  0.308074  43
#
#                     condition_effects              condition_p_values  \
# 2468  {'Wait': 6.495031631824008e-05}    {'Wait': 0.9990935461384604}
# 2541    {'Wait': 0.03133366933058723}    {'Wait': 0.5940623657347524}
# 2736  {'Wait': -0.023245383197625362}    {'Wait': 0.6938736682951339}
# 2791   {'Wait': 0.024661602139640797}     {'Wait': 0.676213956227069}
# 2805    {'Wait': 0.06888505134712572}    {'Wait': 0.3392718367581288}
# 2856    {'Wait': 0.04600726711054636}     {'Wait': 0.505825135930343}
# 2869   {'Wait': -0.14345405348794318}   {'Wait': 0.09122756221234969}
# 3106     {'Wait': 0.1588308192260454}  {'Wait': 0.028851508404639858}
# 3119    {'Wait': 0.01057529712056922}    {'Wait': 0.8811204445199932}
# 3168    {'Wait': 0.05910992469901252}   {'Wait': 0.41050207230874247}
# 3230    {'Wait': 0.03057466123154069}    {'Wait': 0.5275545699606645}
# 3238   {'Wait': -0.03685768461378483}    {'Wait': 0.4825444987910821}
# 4943   {'Wait': -0.01885254139168096}    {'Wait': 0.7359029644116148}
#
#       model_r_squared  model_adj_r_squared  fc_p_value_fdr
# 2468         0.093401             0.048071        0.998294
# 2541         0.105348             0.060616        0.998294
# 2736         0.137527             0.094403        0.998294
# 2791         0.144484             0.101709        0.998294
# 2805         0.140442             0.097464        0.998294
# 2856         0.171871             0.130464        0.998294
# 2869         0.157712             0.115597        0.998294
# 3106         0.191192             0.150751        0.998294
# 3119         0.135991             0.092790        0.998294
# 3168         0.110566             0.066095        0.998294
# 3230         0.126129             0.082435        0.998294
# 3238         0.115739             0.071526        0.998294
# 4943         0.097513             0.052388        0.998294

# %%
condition_baseline_FC_file = os.path.join(data_dir, 'condition_baseline_FC_schaefer_2018_100_7_2_roiroi_fc.csv')
condition_baseline_FC = pd.read_csv(condition_baseline_FC_file)
condition_baseline_FC.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                                          ROI1  \
# 1075                 b'7Networks_LH_SomMot_3'
# 4506          b'7Networks_RH_DorsAttn_Post_4'
# 205                     b'7Networks_LH_Vis_3'
# 301                     b'7Networks_LH_Vis_4'
# 59                      b'7Networks_LH_Vis_1'
# 1112                 b'7Networks_LH_SomMot_3'
# 2166  b'7Networks_LH_SalVentAttn_FrOperIns_1'
# 1999           b'7Networks_LH_DorsAttn_FEF_1'
# 4821              b'7Networks_RH_Cont_PFCl_2'
# 176                     b'7Networks_LH_Vis_2'
# 108                     b'7Networks_LH_Vis_2'
# 2717        b'7Networks_LH_Limbic_TempPole_2'
# 4805              b'7Networks_RH_Cont_PFCl_1'
# 3894                    b'7Networks_RH_Vis_4'
# 3875                    b'7Networks_RH_Vis_4'
# 10                      b'7Networks_LH_Vis_1'
# 1780          b'7Networks_LH_DorsAttn_Post_5'
# 4808              b'7Networks_RH_Cont_PFCl_1'
# 4507          b'7Networks_RH_DorsAttn_Post_4'
# 1074                 b'7Networks_LH_SomMot_3'
#
#                                          ROI2           network1  \
# 1075                    b'7Networks_RH_Vis_4'             Visual
# 4506           b'7Networks_RH_Default_Temp_2'             Limbic
# 205                  b'7Networks_LH_SomMot_3'             Visual
# 301                  b'7Networks_LH_SomMot_3'             Visual
# 59                   b'7Networks_RH_SomMot_3'             Visual
# 1112           b'7Networks_RH_Default_Temp_1'             Visual
# 2166           b'7Networks_RH_Default_Temp_2'        Somatomotor
# 1999  b'7Networks_RH_SalVentAttn_FrOperIns_1'        Somatomotor
# 4821           b'7Networks_RH_Default_Temp_2'     Frontoparietal
# 176         b'7Networks_RH_Limbic_TempPole_1'             Visual
# 108                  b'7Networks_LH_SomMot_3'             Visual
# 2717             b'7Networks_RH_Limbic_OFC_1'   Dorsal Attention
# 4805           b'7Networks_RH_Default_Temp_2'     Frontoparietal
# 3894        b'7Networks_RH_Limbic_TempPole_1'  Ventral Attention
# 3875                 b'7Networks_RH_SomMot_3'  Ventral Attention
# 10                   b'7Networks_LH_SomMot_3'             Visual
# 1780           b'7Networks_RH_Default_Temp_1'        Somatomotor
# 4808           b'7Networks_RH_Default_PFCv_2'     Frontoparietal
# 4507           b'7Networks_RH_Default_Temp_3'             Limbic
# 1074                    b'7Networks_RH_Vis_3'             Visual
#
#                network2 reference_condition comparison_condition  t_statistic  \
# 1075  Ventral Attention               Treat                 Wait    -3.726315
# 4506            Default               Treat                 Wait    -3.370158
# 205              Visual               Treat                 Wait    -3.331100
# 301              Visual               Treat                 Wait    -3.180430
# 59               Limbic               Treat                 Wait    -3.033953
# 1112            Default               Treat                 Wait    -3.010569
# 2166            Default               Treat                 Wait    -2.961664
# 1999     Frontoparietal               Treat                 Wait    -2.925707
# 4821            Default               Treat                 Wait    -2.894475
# 176      Frontoparietal               Treat                 Wait     2.849259
# 108              Visual               Treat                 Wait    -2.829469
# 2717     Frontoparietal               Treat                 Wait     2.820533
# 4805            Default               Treat                 Wait    -2.829550
# 3894     Frontoparietal               Treat                 Wait     2.808910
# 3875             Limbic               Treat                 Wait    -2.797647
# 10               Visual               Treat                 Wait    -2.783011
# 1780            Default               Treat                 Wait    -2.779692
# 4808            Default               Treat                 Wait    -2.798206
# 4507            Default               Treat                 Wait    -2.769923
# 1074  Ventral Attention               Treat                 Wait    -2.762945
#
#        p_value  reference_mean  comparison_mean  reference_n  comparison_n  \
# 1075  0.000594        0.457286         0.290706           24            22
# 4506  0.001582        0.376938         0.218476           24            22
# 205   0.001759        0.444040         0.261060           24            22
# 301   0.002809        0.486578         0.331584           24            22
# 59    0.004057        0.254364         0.059500           24            22
# 1112  0.004321        0.246633         0.057572           24            22
# 2166  0.004992        0.587372         0.454786           24            22
# 1999  0.005418        0.531878         0.404843           24            22
# 4821  0.006079        0.369738         0.200384           24            22
# 176   0.006763        0.243670         0.383410           24            22
# 108   0.007008        0.469143         0.312279           24            22
# 2717  0.007172        0.200171         0.346047           24            22
# 4805  0.007208        0.423949         0.271243           24            22
# 3894  0.007527        0.291751         0.433675           24            22
# 3875  0.007860        0.423494         0.262433           24            22
# 10    0.007907        0.243317         0.054608           24            22
# 1780  0.008051        0.320261         0.159755           24            22
# 4808  0.008198        0.577916         0.430323           24            22
# 4507  0.008242        0.347763         0.184042           24            22
# 1074  0.008344        0.500107         0.377707           24            22
#
#       effect_size  p_value_fdr
# 1075    -1.129961     0.896046
# 4506    -1.012908     0.896046
# 205     -1.003578     0.896046
# 301     -0.964115     0.896046
# 59      -0.915738     0.896046
# 1112    -0.905045     0.896046
# 2166    -0.895889     0.896046
# 1999    -0.881293     0.896046
# 4821    -0.877497     0.896046
# 176      0.862515     0.896046
# 108     -0.853427     0.896046
# 2717     0.848543     0.896046
# 4805    -0.857848     0.896046
# 3894     0.850481     0.896046
# 3875    -0.848537     0.896046
# 10      -0.837862     0.896046
# 1780    -0.834095     0.896046
# 4808    -0.851935     0.896046
# 4507    -0.831514     0.896046
# 1074    -0.833528     0.896046

# %%
condition_followup_FC_file = os.path.join(data_dir, 'condition_followup_FC_schaefer_2018_100_7_2_roiroi_fc.csv')
condition_followup_FC = pd.read_csv(condition_followup_FC_file)
condition_followup_FC.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                                     ROI1                               ROI2  \
# 18                 b'7Networks_LH_Vis_1'    b'7Networks_LH_DorsAttn_Post_5'
# 3571       b'7Networks_LH_Default_PFC_6'  b'7Networks_RH_Default_pCunPCC_2'
# 3572       b'7Networks_LH_Default_PFC_7'  b'7Networks_LH_Default_pCunPCC_1'
# 3521       b'7Networks_LH_Default_PFC_6'  b'7Networks_LH_Default_pCunPCC_2'
# 3623       b'7Networks_LH_Default_PFC_7'  b'7Networks_RH_Default_pCunPCC_2'
# 2869         b'7Networks_LH_Cont_PFCl_1'  b'7Networks_RH_Default_pCunPCC_2'
# 3743               b'7Networks_RH_Vis_1'    b'7Networks_RH_DorsAttn_Post_4'
# 2818         b'7Networks_LH_Cont_PFCl_1'  b'7Networks_LH_Default_pCunPCC_1'
# 3827               b'7Networks_RH_Vis_3'           b'7Networks_RH_SomMot_1'
# 1993      b'7Networks_LH_DorsAttn_FEF_1'    b'7Networks_RH_DorsAttn_Post_4'
# 3875               b'7Networks_RH_Vis_4'           b'7Networks_RH_SomMot_3'
# 1073            b'7Networks_LH_SomMot_3'              b'7Networks_RH_Vis_2'
# 2868         b'7Networks_LH_Cont_PFCl_1'  b'7Networks_RH_Default_pCunPCC_1'
# 1579     b'7Networks_LH_DorsAttn_Post_3'              b'7Networks_RH_Vis_1'
# 1075            b'7Networks_LH_SomMot_3'              b'7Networks_RH_Vis_4'
# 2819         b'7Networks_LH_Cont_PFCl_1'  b'7Networks_LH_Default_pCunPCC_2'
# 4948  b'7Networks_RH_Default_PFCdPFCm_3'  b'7Networks_RH_Default_pCunPCC_2'
# 1620     b'7Networks_LH_DorsAttn_Post_3'     b'7Networks_RH_Default_Temp_2'
# 902             b'7Networks_LH_SomMot_1'              b'7Networks_RH_Vis_8'
# 4047               b'7Networks_RH_Vis_8'           b'7Networks_RH_SomMot_1'
#
#                network1           network2 reference_condition  \
# 18               Visual        Somatomotor               Treat
# 3571  Ventral Attention   Dorsal Attention               Treat
# 3572  Ventral Attention  Ventral Attention               Treat
# 3521  Ventral Attention  Ventral Attention               Treat
# 3623  Ventral Attention   Dorsal Attention               Treat
# 2869   Dorsal Attention   Dorsal Attention               Treat
# 3743  Ventral Attention             Limbic               Treat
# 2818   Dorsal Attention  Ventral Attention               Treat
# 3827  Ventral Attention             Limbic               Treat
# 1993        Somatomotor             Limbic               Treat
# 3875  Ventral Attention             Limbic               Treat
# 1073             Visual  Ventral Attention               Treat
# 2868   Dorsal Attention        Somatomotor               Treat
# 1579        Somatomotor  Ventral Attention               Treat
# 1075             Visual  Ventral Attention               Treat
# 2819   Dorsal Attention  Ventral Attention               Treat
# 4948            Default   Dorsal Attention               Treat
# 1620        Somatomotor            Default               Treat
# 902              Visual             Limbic               Treat
# 4047             Limbic             Limbic               Treat
#
#      comparison_condition  t_statistic   p_value  reference_mean  \
# 18                   Wait    -3.973730  0.000286        0.499407
# 3571                 Wait    -3.899778  0.000350        0.371515
# 3572                 Wait    -3.649198  0.000737        0.447241
# 3521                 Wait    -3.550484  0.000982        0.519775
# 3623                 Wait    -3.515667  0.001086        0.445097
# 2869                 Wait    -3.424078  0.001420        0.121302
# 3743                 Wait    -3.344041  0.001787        0.472511
# 2818                 Wait    -3.317439  0.001918        0.234860
# 3827                 Wait    -3.320432  0.002026        0.552034
# 1993                 Wait    -3.285487  0.002325        0.581564
# 3875                 Wait    -3.152052  0.003244        0.438178
# 1073                 Wait    -3.124846  0.003355        0.463924
# 2868                 Wait    -3.107350  0.003424        0.194530
# 1579                 Wait    -3.114528  0.003428        0.476791
# 1075                 Wait    -3.114945  0.003642        0.435555
# 2819                 Wait    -3.081889  0.003678        0.272060
# 4948                 Wait    -3.050428  0.004037        0.563129
# 1620                 Wait    -3.014931  0.004400        0.329799
# 902                  Wait    -3.009741  0.004561        0.559184
# 4047                 Wait    -2.965996  0.005013        0.532042
#
#       comparison_mean  reference_n  comparison_n  effect_size  p_value_fdr
# 18           0.305563           21            22    -1.242860     0.866259
# 3571         0.152159           21            22    -1.217442     0.866259
# 3572         0.267657           21            22    -1.139010     0.951205
# 3521         0.346676           21            22    -1.108392     0.951205
# 3623         0.254852           21            22    -1.098012     0.951205
# 2869        -0.101608           21            22    -1.070297     0.951205
# 3743         0.347471           21            22    -1.045591     0.951205
# 2818         0.043713           21            22    -1.036837     0.951205
# 3827         0.379695           21            22    -1.032734     0.951205
# 1993         0.419092           21            22    -1.020714     0.951205
# 3875         0.236085           21            22    -0.979964     0.951205
# 1073         0.298513           21            22    -0.973016     0.951205
# 2868         0.002716           21            22    -0.970620     0.951205
# 1579         0.324762           21            22    -0.970138     0.951205
# 1075         0.237860           21            22    -0.967926     0.951205
# 2819         0.089104           21            22    -0.961484     0.951205
# 4948         0.433409           21            22    -0.950821     0.951205
# 1620         0.165551           21            22    -0.940980     0.951205
# 902          0.420838           21            22    -0.937294     0.951205
# 4047         0.399650           21            22    -0.926202     0.951205

# %%
condition_FC_change_file = os.path.join(data_dir, 'condition_FC_change_schaefer_2018_100_7_2_roiroi_fc.csv')
condition_FC_change = pd.read_csv(condition_FC_change_file)
condition_FC_change.sort_values(by='p_value', ascending=True).head(20)
# Out:
#                                          ROI1  \
# 2196  b'7Networks_LH_SalVentAttn_FrOperIns_2'
# 3156            b'7Networks_LH_Default_Par_1'
# 1874          b'7Networks_LH_DorsAttn_PrCv_1'
# 1473          b'7Networks_LH_DorsAttn_Post_2'
# 3868                    b'7Networks_RH_Vis_3'
# 4421          b'7Networks_RH_DorsAttn_Post_1'
# 2404        b'7Networks_LH_SalVentAttn_Med_2'
# 3246            b'7Networks_LH_Default_PFC_1'
# 2872              b'7Networks_LH_Cont_pCun_1'
# 2864              b'7Networks_LH_Cont_PFCl_1'
# 3338            b'7Networks_LH_Default_PFC_2'
# 2341        b'7Networks_LH_SalVentAttn_Med_1'
# 2969              b'7Networks_LH_Cont_Cing_1'
# 3330            b'7Networks_LH_Default_PFC_2'
# 4322                 b'7Networks_RH_SomMot_7'
# 4691        b'7Networks_RH_SalVentAttn_Med_1'
# 2264       b'7Networks_LH_SalVentAttn_PFCl_1'
# 3331            b'7Networks_LH_Default_PFC_2'
# 3611            b'7Networks_LH_Default_PFC_7'
# 3573            b'7Networks_LH_Default_PFC_7'
#
#                                     ROI2           network1  \
# 2196       b'7Networks_LH_Default_PFC_7'        Somatomotor
# 3156   b'7Networks_RH_SalVentAttn_Med_1'   Dorsal Attention
# 1874   b'7Networks_LH_SalVentAttn_Med_1'        Somatomotor
# 1473  b'7Networks_LH_SalVentAttn_PFCl_1'        Somatomotor
# 3868   b'7Networks_RH_Default_pCunPCC_2'  Ventral Attention
# 4421   b'7Networks_RH_Default_pCunPCC_2'             Limbic
# 2404       b'7Networks_LH_Default_Par_1'   Dorsal Attention
# 3246   b'7Networks_LH_Default_pCunPCC_2'   Dorsal Attention
# 2872      b'7Networks_LH_Default_Temp_2'   Dorsal Attention
# 2864      b'7Networks_RH_Default_PFCv_2'   Dorsal Attention
# 3338         b'7Networks_RH_Cont_PFCl_3'  Ventral Attention
# 2341       b'7Networks_LH_Default_PFC_7'        Somatomotor
# 2969      b'7Networks_RH_DorsAttn_FEF_1'   Dorsal Attention
# 3330   b'7Networks_RH_SalVentAttn_Med_1'  Ventral Attention
# 4322     b'7Networks_RH_DorsAttn_Post_2'             Limbic
# 4691      b'7Networks_RH_Default_PFCv_2'     Frontoparietal
# 2264       b'7Networks_LH_Default_PFC_2'        Somatomotor
# 3331   b'7Networks_RH_SalVentAttn_Med_2'  Ventral Attention
# 3611        b'7Networks_RH_Cont_PFCmp_1'  Ventral Attention
# 3573   b'7Networks_LH_Default_pCunPCC_2'  Ventral Attention
#
#                network2 reference_condition comparison_condition  t_statistic  \
# 2196  Ventral Attention               Treat                 Wait     3.208432
# 3156     Frontoparietal               Treat                 Wait     3.234843
# 1874        Somatomotor               Treat                 Wait     3.090979
# 1473        Somatomotor               Treat                 Wait     3.036572
# 3868   Dorsal Attention               Treat                 Wait    -2.931750
# 4421   Dorsal Attention               Treat                 Wait    -2.943008
# 2404   Dorsal Attention               Treat                 Wait     2.885596
# 3246  Ventral Attention               Treat                 Wait    -2.768220
# 2872   Dorsal Attention               Treat                 Wait     2.741681
# 2864            Default               Treat                 Wait     2.739552
# 3338            Default               Treat                 Wait     2.728752
# 2341  Ventral Attention               Treat                 Wait     2.628824
# 2969     Frontoparietal               Treat                 Wait    -2.624697
# 3330     Frontoparietal               Treat                 Wait     2.613677
# 4322             Limbic               Treat                 Wait     2.623101
# 4691            Default               Treat                 Wait     2.602193
# 2264  Ventral Attention               Treat                 Wait     2.584874
# 3331     Frontoparietal               Treat                 Wait     2.562310
# 3611            Default               Treat                 Wait     2.557948
# 3573  Ventral Attention               Treat                 Wait    -2.561479
#
#        p_value  reference_mean  comparison_mean  reference_n  comparison_n  \
# 2196  0.002750       -0.126760         0.095983           21            22
# 3156  0.002775       -0.136267         0.110952           21            22
# 1874  0.003579       -0.105044         0.090734           21            22
# 1473  0.004194       -0.076822         0.113690           21            22
# 3868  0.005492        0.104509        -0.107928           21            22
# 4421  0.005813        0.037733        -0.101204           21            22
# 2404  0.006437       -0.083306         0.116690           21            22
# 3246  0.008429        0.056045        -0.103902           21            22
# 2872  0.009148       -0.109059         0.090952           21            22
# 2864  0.009220       -0.139074         0.034356           21            22
# 3338  0.009485       -0.130790         0.076532           21            22
# 2341  0.012274       -0.129585         0.028862           21            22
# 2969  0.012318        0.023594        -0.140725           21            22
# 3330  0.012473       -0.111024         0.097442           21            22
# 4322  0.012730       -0.036451         0.076713           21            22
# 4691  0.013055       -0.100428         0.091634           21            22
# 2264  0.013400       -0.106489         0.052325           21            22
# 3331  0.014190       -0.135865         0.018609           21            22
# 3611  0.014396       -0.111963         0.052604           21            22
# 3573  0.014515        0.039514        -0.081604           21            22
#
#       effect_size  p_value_fdr
# 2196     1.005815     0.999792
# 3156     1.016285     0.999792
# 1874     0.965406     0.999792
# 1473     0.949951     0.999792
# 3868    -0.915289     0.999792
# 4421    -0.913963     0.999792
# 2404     0.904368     0.999792
# 3246    -0.863914     0.999792
# 2872     0.858233     0.999792
# 2864     0.853151     0.999792
# 3338     0.849730     0.999792
# 2341     0.818174     0.999792
# 2969    -0.817334     0.999792
# 3330     0.815848     0.999792
# 4322     0.815267     0.999792
# 4691     0.814952     0.999792
# 2264     0.807371     0.999792
# 3331     0.799384     0.999792
# 3611     0.800051     0.999792
# 3573    -0.797108     0.999792
